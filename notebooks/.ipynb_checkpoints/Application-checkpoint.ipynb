# %%
import pm4py

log = pm4py.read_xes("BPI_Challenge_2019.xes")
# Out:
# parsing log, completed traces ::   0%|          | 0/251734 [00:00<?, ?it/s]
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)
# /Users/adrianrebmann/Develop/ocel-to-docel/env/lib/python3.9/site-packages/pm4py/objects/log/util/dataframe_utils.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], utc=True)

# %%
cases_to_keep = []
for case_id, events in log.groupby("case:concept:name"):
    if events["Cumulative net worth (EUR)"].nunique()>1:
        cases_to_keep.append(case_id)
print("keeping", len(cases_to_keep), "cases")
log = log[log["case:concept:name"].isin(cases_to_keep)]
pm4py.write_xes(log, "../input/BPI_Challenge_2019_dynamic.xes", case_id_key='case:concept:name')
# Out:
# keeping 4632 cases
# exporting log, completed traces ::   0%|          | 0/4632 [00:00<?, ?it/s]

# %%
log
# Out:
#              User org:resource                         concept:name
# 1524     batch_00     batch_00                         SRM: Created  \
# 1525     batch_00     batch_00                        SRM: Complete
# 1526     batch_00     batch_00               SRM: Awaiting Approval
# 1527     batch_00     batch_00              SRM: Document Completed
# 1528     batch_00     batch_00  SRM: In Transfer to Execution Syst.
# ...           ...          ...                                  ...
# 1590020      NONE         NONE           Record Service Entry Sheet
# 1590021      NONE         NONE           Record Service Entry Sheet
# 1590022      NONE         NONE           Record Service Entry Sheet
# 1590023  batch_02     batch_02                 Record Goods Receipt
# 1590024  batch_02     batch_02                 Record Goods Receipt
#
#          Cumulative net worth (EUR)            time:timestamp
# 1524                          549.0 2018-01-15 13:51:00+00:00  \
# 1525                          549.0 2018-01-15 14:51:00+00:00
# 1526                          549.0 2018-01-15 14:51:00+00:00
# 1527                          549.0 2018-01-15 14:51:00+00:00
# 1528                          549.0 2018-01-15 14:51:00+00:00
# ...                             ...                       ...
# 1590020                        47.0 2018-12-31 22:34:00+00:00
# 1590021                        47.0 2018-12-31 22:34:00+00:00
# 1590022                        47.0 2018-12-31 22:34:00+00:00
# 1590023                      2577.0 2018-12-31 22:34:00+00:00
# 1590024                      2052.0 2018-12-31 22:34:00+00:00
#
#         case:Spend area text    case:Company case:Document Type
# 1524            CAPEX & SOCS  companyID_0000  EC Purchase order  \
# 1525            CAPEX & SOCS  companyID_0000  EC Purchase order
# 1526            CAPEX & SOCS  companyID_0000  EC Purchase order
# 1527            CAPEX & SOCS  companyID_0000  EC Purchase order
# 1528            CAPEX & SOCS  companyID_0000  EC Purchase order
# ...                      ...             ...                ...
# 1590020            Logistics  companyID_0000        Standard PO
# 1590021            Logistics  companyID_0000        Standard PO
# 1590022            Logistics  companyID_0000        Standard PO
# 1590023            Logistics  companyID_0000        Standard PO
# 1590024            Logistics  companyID_0000        Standard PO
#
#                case:Sub spend area text case:Purchasing Document  ...
# 1524     Laboratory Supplies & Services               2000000030  ...  \
# 1525     Laboratory Supplies & Services               2000000030  ...
# 1526     Laboratory Supplies & Services               2000000030  ...
# 1527     Laboratory Supplies & Services               2000000030  ...
# 1528     Laboratory Supplies & Services               2000000030  ...
# ...                                 ...                      ...  ...
# 1590020                     Road Packed               4508075963  ...
# 1590021                     Road Packed               4508075963  ...
# 1590022                     Road Packed               4508075963  ...
# 1590023                     Road Packed               4508075963  ...
# 1590024                     Road Packed               4508075963  ...
#
#            case:Vendor case:Item Type             case:Item Category
# 1524     vendorID_0012        Service  3-way match, invoice after GR  \
# 1525     vendorID_0012        Service  3-way match, invoice after GR
# 1526     vendorID_0012        Service  3-way match, invoice after GR
# 1527     vendorID_0012        Service  3-way match, invoice after GR
# 1528     vendorID_0012        Service  3-way match, invoice after GR
# ...                ...            ...                            ...
# 1590020  vendorID_0234        Service  3-way match, invoice after GR
# 1590021  vendorID_0234        Service  3-way match, invoice after GR
# 1590022  vendorID_0234        Service  3-way match, invoice after GR
# 1590023  vendorID_0234        Service  3-way match, invoice after GR
# 1590024  vendorID_0234        Service  3-way match, invoice after GR
#
#         case:Spend classification text          case:Source    case:Name
# 1524                               NPR  sourceSystemID_0000  vendor_0012  \
# 1525                               NPR  sourceSystemID_0000  vendor_0012
# 1526                               NPR  sourceSystemID_0000  vendor_0012
# 1527                               NPR  sourceSystemID_0000  vendor_0012
# 1528                               NPR  sourceSystemID_0000  vendor_0012
# ...                                ...                  ...          ...
# 1590020                            NPR  sourceSystemID_0000  vendor_0229
# 1590021                            NPR  sourceSystemID_0000  vendor_0229
# 1590022                            NPR  sourceSystemID_0000  vendor_0229
# 1590023                            NPR  sourceSystemID_0000  vendor_0229
# 1590024                            NPR  sourceSystemID_0000  vendor_0229
#
#         case:GR-Based Inv. Verif.  case:Item case:concept:name
# 1524                         True      00001  2000000030_00001  \
# 1525                         True      00001  2000000030_00001
# 1526                         True      00001  2000000030_00001
# 1527                         True      00001  2000000030_00001
# 1528                         True      00001  2000000030_00001
# ...                           ...        ...               ...
# 1590020                      True      00001  4508075963_00001
# 1590021                      True      00001  4508075963_00001
# 1590022                      True      00001  4508075963_00001
# 1590023                      True      00001  4508075963_00001
# 1590024                      True      00001  4508075963_00001
#
#         case:Goods Receipt
# 1524                  True
# 1525                  True
# 1526                  True
# 1527                  True
# 1528                  True
# ...                    ...
# 1590020               True
# 1590021               True
# 1590022               True
# 1590023               True
# 1590024               True
#
# [242020 rows x 21 columns]

# %%
import pm4py

log = pm4py.read_xes("BPI Challenge 2017.xes")
# Out:
# parsing log, completed traces ::   0%|          | 0/31509 [00:00<?, ?it/s]

# %%
import random
all_cases = list(log["case:concept:name"].unique())
sample_cases = random.choices(all_cases, k=1000)

sampled_log = log[log["case:concept:name"].isin(sample_cases)]
sampled_log
# Out:
#               Action org:resource             concept:name  EventOrigin  \
# 994          Created       User_1     A_Create Application  Application
# 995      statechange       User_1              A_Submitted  Application
# 996          Created       User_1           W_Handle leads     Workflow
# 997         Obtained      User_17           W_Handle leads     Workflow
# 998          Deleted      User_17           W_Handle leads     Workflow
# ...              ...          ...                      ...          ...
# 1201086     Obtained      User_66  W_Call incomplete files     Workflow
# 1201087     Released      User_66  W_Call incomplete files     Workflow
# 1201088  statechange     User_133               O_Accepted        Offer
# 1201089  statechange     User_133                A_Pending  Application
# 1201090      Deleted     User_133  W_Call incomplete files     Workflow
#
#                         EventID lifecycle:transition  \
# 994      Application_1197857445             complete
# 995        ApplState_1462316123             complete
# 996         Workitem_1424421778             schedule
# 997         Workitem_1510265530                start
# 998          Workitem_511074407             complete
# ...                         ...                  ...
# 1201086     Workitem_1127813592               resume
# 1201087     Workitem_2040777815              suspend
# 1201088    OfferState_833440508             complete
# 1201089    ApplState_1796265526             complete
# 1201090       Workitem_29478990            ate_abort
#
#                           time:timestamp     case:LoanGoal  \
# 994     2016-01-02 09:33:11.203000+00:00  Home improvement
# 995     2016-01-02 09:33:11.257000+00:00  Home improvement
# 996     2016-01-02 09:33:11.860000+00:00  Home improvement
# 997     2016-01-02 09:46:06.071000+00:00  Home improvement
# 998     2016-01-02 09:46:40.252000+00:00  Home improvement
# ...                                  ...               ...
# 1201086 2017-01-16 09:03:32.327000+00:00  Home improvement
# 1201087 2017-01-16 09:06:39.355000+00:00  Home improvement
# 1201088 2017-01-16 16:49:39.149000+00:00  Home improvement
# 1201089 2017-01-16 16:49:39.152000+00:00  Home improvement
# 1201090 2017-01-16 16:49:39.155000+00:00  Home improvement
#
#         case:ApplicationType       case:concept:name  case:RequestedAmount  \
# 994               New credit  Application_1197857445                6000.0
# 995               New credit  Application_1197857445                6000.0
# 996               New credit  Application_1197857445                6000.0
# 997               New credit  Application_1197857445                6000.0
# 998               New credit  Application_1197857445                6000.0
# ...                      ...                     ...                   ...
# 1201086           New credit  Application_1729852643               10000.0
# 1201087           New credit  Application_1729852643               10000.0
# 1201088           New credit  Application_1729852643               10000.0
# 1201089           New credit  Application_1729852643               10000.0
# 1201090           New credit  Application_1729852643               10000.0
#
#          FirstWithdrawalAmount  NumberOfTerms Accepted  MonthlyCost Selected  \
# 994                        NaN            NaN      NaN          NaN      NaN
# 995                        NaN            NaN      NaN          NaN      NaN
# 996                        NaN            NaN      NaN          NaN      NaN
# 997                        NaN            NaN      NaN          NaN      NaN
# 998                        NaN            NaN      NaN          NaN      NaN
# ...                        ...            ...      ...          ...      ...
# 1201086                    NaN            NaN      NaN          NaN      NaN
# 1201087                    NaN            NaN      NaN          NaN      NaN
# 1201088                    NaN            NaN      NaN          NaN      NaN
# 1201089                    NaN            NaN      NaN          NaN      NaN
# 1201090                    NaN            NaN      NaN          NaN      NaN
#
#          CreditScore  OfferedAmount          OfferID
# 994              NaN            NaN              NaN
# 995              NaN            NaN              NaN
# 996              NaN            NaN              NaN
# 997              NaN            NaN              NaN
# 998              NaN            NaN              NaN
# ...              ...            ...              ...
# 1201086          NaN            NaN              NaN
# 1201087          NaN            NaN              NaN
# 1201088          NaN            NaN  Offer_886827905
# 1201089          NaN            NaN              NaN
# 1201090          NaN            NaN              NaN
#
# [37000 rows x 19 columns]

# %%
for case_id, case in sampled_log.groupby("case:concept:name"):
    case = case.sort_values(by='time:timestamp') 
    current_state = "False"
    for idx, row in case.iterrows():
        if row["Accepted"] == True:
            current_state = "True"
        sampled_log.at[idx, "Accepted"] = current_state
altered_log = sampled_log.sort_values(by='case:concept:name')
# Out:
#              Action org:resource              concept:name EventOrigin  \
# 518376  statechange      User_48  O_Sent (mail and online)       Offer
# 518395      Deleted      User_30    W_Validate application    Workflow
# 518394     Obtained      User_30    W_Validate application    Workflow
# 518393     Released      User_30    W_Validate application    Workflow
# 518392     Obtained      User_30    W_Validate application    Workflow
# ...             ...          ...                       ...         ...
# 120326     Obtained      User_87    W_Validate application    Workflow
# 120330     Released      User_68    W_Validate application    Workflow
# 120318  statechange      User_28                 O_Created       Offer
# 120319  statechange      User_28      O_Sent (online only)       Offer
# 120317      Created      User_28            O_Create Offer       Offer
#
#                       EventID lifecycle:transition  \
# 518376   OfferState_346685638             complete
# 518395    Workitem_1737564349             complete
# 518394     Workitem_873792634               resume
# 518393     Workitem_944395762              suspend
# 518392     Workitem_582234219               resume
# ...                       ...                  ...
# 120326     Workitem_694020246               resume
# 120330    Workitem_2133678380              suspend
# 120318  OfferState_1868233863             complete
# 120319   OfferState_715987807             complete
# 120317       Offer_2003423832             complete
#
#                          time:timestamp           case:LoanGoal  \
# 518376 2016-06-21 11:15:01.373000+00:00                 Unknown
# 518395 2016-07-07 10:56:10.857000+00:00                 Unknown
# 518394 2016-07-07 10:30:01.160000+00:00                 Unknown
# 518393 2016-07-07 10:10:07.144000+00:00                 Unknown
# 518392 2016-07-07 10:09:57.243000+00:00                 Unknown
# ...                                 ...                     ...
# 120326 2016-02-23 06:10:07.555000+00:00  Existing loan takeover
# 120330 2016-02-23 10:58:05.264000+00:00  Existing loan takeover
# 120318 2016-02-18 11:10:39.528000+00:00  Existing loan takeover
# 120319 2016-02-18 11:12:22.182000+00:00  Existing loan takeover
# 120317 2016-02-18 11:10:37.766000+00:00  Existing loan takeover
#
#        case:ApplicationType       case:concept:name  case:RequestedAmount  \
# 518376           New credit  Application_1002843616                   0.0
# 518395           New credit  Application_1002843616                   0.0
# 518394           New credit  Application_1002843616                   0.0
# 518393           New credit  Application_1002843616                   0.0
# 518392           New credit  Application_1002843616                   0.0
# ...                     ...                     ...                   ...
# 120326           New credit   Application_999352398               45000.0
# 120330           New credit   Application_999352398               45000.0
# 120318           New credit   Application_999352398               45000.0
# 120319           New credit   Application_999352398               45000.0
# 120317           New credit   Application_999352398               45000.0
#
#         FirstWithdrawalAmount  NumberOfTerms Accepted  MonthlyCost Selected  \
# 518376                    NaN            NaN     True          NaN      NaN
# 518395                    NaN            NaN     True          NaN      NaN
# 518394                    NaN            NaN     True          NaN      NaN
# 518393                    NaN            NaN     True          NaN      NaN
# 518392                    NaN            NaN     True          NaN      NaN
# ...                       ...            ...      ...          ...      ...
# 120326                    NaN            NaN     True          NaN      NaN
# 120330                    NaN            NaN     True          NaN      NaN
# 120318                    NaN            NaN     True          NaN      NaN
# 120319                    NaN            NaN     True          NaN      NaN
# 120317                 2000.0          126.0     True        730.0     True
#
#         CreditScore  OfferedAmount           OfferID
# 518376          NaN            NaN   Offer_977820773
# 518395          NaN            NaN               NaN
# 518394          NaN            NaN               NaN
# 518393          NaN            NaN               NaN
# 518392          NaN            NaN               NaN
# ...             ...            ...               ...
# 120326          NaN            NaN               NaN
# 120330          NaN            NaN               NaN
# 120318          NaN            NaN  Offer_2003423832
# 120319          NaN            NaN  Offer_2003423832
# 120317        905.0        73000.0               NaN
#
# [21103 rows x 19 columns]

# %%
pm4py.write_xes(altered_log, "BPI_Challenge_2017.xes", case_id_key='case:concept:name')
# Out:
# exporting log, completed traces ::   0%|          | 0/990 [00:00<?, ?it/s]

# %%
import ocel
ocel_log = ocel.import_log("BPI_Challenge_2017.xes.jsonocel")

# %%
ocel_log
# Out:
# {'ocel:global-event': {'ocel:activity': '__INVALID__'},
#  'ocel:global-object': {'ocel:type': '__INVALID__'},
#  'ocel:global-log': {'ocel:attribute-names': ['MonthlyCost',
#    'case:RequestedAmount',
#    'case:ApplicationType',
#    'OfferedAmount',
#    'FirstWithdrawalAmount',
#    'case:LoanGoal'],
#   'ocel:object-types': ['application',
#    'resource',
#    'offer',
#    'mail',
#    'credit',
#    'term',
#    'potential fraud',
#    'personal loan']},
#  'ocel:events': {'1': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 9, 51, 15, 304000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_652823628'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_652823628',
#     'lifecycle:transition': 'complete'}},
#   '2': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 9, 51, 15, 352000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_652823628'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1582051990',
#     'lifecycle:transition': 'complete'}},
#   '3': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 9, 51, 15, 774000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_652823628'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1298499574',
#     'lifecycle:transition': 'schedule'}},
#   '4': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 9, 52, 36, 392000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_652823628'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1673366067',
#     'lifecycle:transition': 'withdraw'}},
#   '5': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 9, 52, 36, 403000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_652823628'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1493664571',
#     'lifecycle:transition': 'schedule'}},
#   '6': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 9, 52, 36, 413000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_652823628'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_642383566',
#     'lifecycle:transition': 'complete'}},
#   '7': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 10, 16, 11, 500000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1691306052'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1691306052',
#     'lifecycle:transition': 'complete'}},
#   '8': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 10, 16, 11, 549000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1691306052'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_284636842',
#     'lifecycle:transition': 'complete'}},
#   '9': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 10, 16, 11, 740000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1691306052'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_831373279',
#     'lifecycle:transition': 'schedule'}},
#   '10': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 10, 17, 31, 573000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1691306052'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1299098074',
#     'lifecycle:transition': 'withdraw'}},
#   '11': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 10, 17, 31, 584000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1691306052'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1703931302',
#     'lifecycle:transition': 'schedule'}},
#   '12': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 10, 17, 31, 594000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1691306052'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_421204851',
#     'lifecycle:transition': 'complete'}},
#   '13': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 11, 19, 38, 177000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_428409768'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_428409768',
#     'lifecycle:transition': 'complete'}},
#   '14': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 11, 19, 38, 235000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_428409768'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_105207793',
#     'lifecycle:transition': 'complete'}},
#   '15': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 11, 19, 38, 914000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_428409768'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1185806608',
#     'lifecycle:transition': 'schedule'}},
#   '16': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 11, 20, 37, 391000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_428409768'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_835967796',
#     'lifecycle:transition': 'withdraw'}},
#   '17': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 11, 20, 37, 409000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_428409768'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_755889823',
#     'lifecycle:transition': 'schedule'}},
#   '18': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 11, 20, 37, 422000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_428409768'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1727723699',
#     'lifecycle:transition': 'complete'}},
#   '19': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 12, 34, 53, 911000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1746793196'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1746793196',
#     'lifecycle:transition': 'complete'}},
#   '20': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 12, 34, 53, 950000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1746793196'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_282472804',
#     'lifecycle:transition': 'complete'}},
#   '21': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 12, 34, 54, 320000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1746793196'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1676837235',
#     'lifecycle:transition': 'schedule'}},
#   '22': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 0, 4, 360000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_828200680'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_828200680',
#     'lifecycle:transition': 'complete'}},
#   '23': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 0, 4, 398000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_828200680'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_420123528',
#     'lifecycle:transition': 'complete'}},
#   '24': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 0, 4, 737000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_828200680'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1645277487',
#     'lifecycle:transition': 'schedule'}},
#   '25': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 1, 44, 651000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_828200680'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1902399339',
#     'lifecycle:transition': 'withdraw'}},
#   '26': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 1, 44, 661000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_828200680'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1933317539',
#     'lifecycle:transition': 'schedule'}},
#   '27': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 1, 44, 671000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_828200680'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_281446729',
#     'lifecycle:transition': 'complete'}},
#   '28': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 5, 19, 866000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1085880569'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1085880569',
#     'lifecycle:transition': 'complete'}},
#   '29': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 5, 19, 901000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1085880569'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_736842791',
#     'lifecycle:transition': 'complete'}},
#   '30': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 5, 20, 88000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1085880569'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_957861555',
#     'lifecycle:transition': 'schedule'}},
#   '31': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 6, 26, 301000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1085880569'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_237665452',
#     'lifecycle:transition': 'withdraw'}},
#   '32': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 6, 26, 311000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1085880569'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_111979908',
#     'lifecycle:transition': 'schedule'}},
#   '33': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 6, 26, 321000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1085880569'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1145436902',
#     'lifecycle:transition': 'complete'}},
#   '34': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 22, 19, 758000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1266995739'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1266995739',
#     'lifecycle:transition': 'complete'}},
#   '35': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 22, 19, 796000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1266995739'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1503316651',
#     'lifecycle:transition': 'complete'}},
#   '36': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 22, 19, 977000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1266995739'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_124706175',
#     'lifecycle:transition': 'schedule'}},
#   '37': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 23, 29, 483000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1266995739'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_476094580',
#     'lifecycle:transition': 'withdraw'}},
#   '38': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 23, 29, 499000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1266995739'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1061838630',
#     'lifecycle:transition': 'schedule'}},
#   '39': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 23, 29, 511000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1266995739'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_287418819',
#     'lifecycle:transition': 'complete'}},
#   '40': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 35, 26, 422000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1878239836', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1878239836',
#     'lifecycle:transition': 'complete'}},
#   '41': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 35, 26, 463000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1878239836', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_649299817',
#     'lifecycle:transition': 'complete'}},
#   '42': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 35, 26, 664000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1878239836', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1693495632',
#     'lifecycle:transition': 'schedule'}},
#   '43': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 36, 30, 982000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1878239836', 'User_1'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1080257214',
#     'lifecycle:transition': 'withdraw'}},
#   '44': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 36, 30, 993000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1878239836', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1531288681',
#     'lifecycle:transition': 'schedule'}},
#   '45': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 13, 36, 31, 3000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1878239836', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_70781426',
#     'lifecycle:transition': 'complete'}},
#   '46': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 13, 16, 64000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_619403287', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_619403287',
#     'lifecycle:transition': 'complete'}},
#   '47': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 13, 16, 117000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_619403287', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1207742536',
#     'lifecycle:transition': 'complete'}},
#   '48': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 13, 16, 371000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_619403287', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_2007616906',
#     'lifecycle:transition': 'schedule'}},
#   '49': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 14, 33, 830000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_619403287', 'User_1'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_993441789',
#     'lifecycle:transition': 'withdraw'}},
#   '50': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 14, 33, 847000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_619403287', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1343236029',
#     'lifecycle:transition': 'schedule'}},
#   '51': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 14, 33, 857000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_619403287', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1877855588',
#     'lifecycle:transition': 'complete'}},
#   '52': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 23, 21, 334000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1710223761', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1710223761',
#     'lifecycle:transition': 'complete'}},
#   '53': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 23, 21, 381000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1710223761', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_575564150',
#     'lifecycle:transition': 'complete'}},
#   '54': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 23, 21, 738000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1710223761', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_614526052',
#     'lifecycle:transition': 'schedule'}},
#   '55': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 24, 54, 517000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1710223761', 'User_1'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_963622468',
#     'lifecycle:transition': 'withdraw'}},
#   '56': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 24, 54, 528000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1710223761', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_268897758',
#     'lifecycle:transition': 'schedule'}},
#   '57': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 24, 54, 538000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1710223761', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1784923327',
#     'lifecycle:transition': 'complete'}},
#   '58': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 42, 36, 728000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1529124572'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1529124572',
#     'lifecycle:transition': 'complete'}},
#   '59': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 42, 36, 767000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1529124572'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1427234050',
#     'lifecycle:transition': 'complete'}},
#   '60': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 42, 37, 143000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1529124572'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_594656343',
#     'lifecycle:transition': 'schedule'}},
#   '61': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 43, 30, 747000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1529124572'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_110419263',
#     'lifecycle:transition': 'withdraw'}},
#   '62': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 43, 30, 758000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1529124572'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_289490153',
#     'lifecycle:transition': 'schedule'}},
#   '63': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 14, 43, 30, 767000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1529124572'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1003788210',
#     'lifecycle:transition': 'complete'}},
#   '64': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 0, 1, 353000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_387012864', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_387012864',
#     'lifecycle:transition': 'complete'}},
#   '65': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 0, 1, 386000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_387012864', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_587211695',
#     'lifecycle:transition': 'complete'}},
#   '66': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 0, 1, 562000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_387012864', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1856767053',
#     'lifecycle:transition': 'schedule'}},
#   '67': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 1, 36, 523000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_387012864', 'User_1'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1532575372',
#     'lifecycle:transition': 'withdraw'}},
#   '68': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 1, 36, 534000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_387012864', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1111825947',
#     'lifecycle:transition': 'schedule'}},
#   '69': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 1, 36, 547000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_387012864', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1788519445',
#     'lifecycle:transition': 'complete'}},
#   '70': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 22, 50, 533000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1120819670'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1120819670',
#     'lifecycle:transition': 'complete'}},
#   '71': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 22, 50, 567000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1120819670'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1884976310',
#     'lifecycle:transition': 'complete'}},
#   '72': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 22, 50, 932000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1120819670'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_2108699659',
#     'lifecycle:transition': 'schedule'}},
#   '73': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 23, 36, 74000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1120819670'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1970934832',
#     'lifecycle:transition': 'withdraw'}},
#   '74': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 23, 36, 85000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1120819670'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_415518642',
#     'lifecycle:transition': 'schedule'}},
#   '75': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 23, 36, 96000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1120819670'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1970342959',
#     'lifecycle:transition': 'complete'}},
#   '76': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 58, 48, 775000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_42838382'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_42838382',
#     'lifecycle:transition': 'complete'}},
#   '77': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 58, 48, 810000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_42838382'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1364915147',
#     'lifecycle:transition': 'complete'}},
#   '78': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 58, 48, 978000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_42838382'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_991596960',
#     'lifecycle:transition': 'schedule'}},
#   '79': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 59, 29, 685000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_42838382'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1341087871',
#     'lifecycle:transition': 'withdraw'}},
#   '80': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 59, 29, 694000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_42838382'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_465973570',
#     'lifecycle:transition': 'schedule'}},
#   '81': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 16, 59, 29, 704000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_42838382'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1041069551',
#     'lifecycle:transition': 'complete'}},
#   '82': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 4, 16, 739000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_180547487'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_180547487',
#     'lifecycle:transition': 'complete'}},
#   '83': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 4, 16, 773000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_180547487'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_649214987',
#     'lifecycle:transition': 'complete'}},
#   '84': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 4, 16, 957000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_180547487'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_250816843',
#     'lifecycle:transition': 'schedule'}},
#   '85': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 5, 29, 607000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_180547487'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_267125598',
#     'lifecycle:transition': 'withdraw'}},
#   '86': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 5, 29, 632000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_180547487'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1542061975',
#     'lifecycle:transition': 'schedule'}},
#   '87': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 5, 29, 642000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_180547487'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_460002192',
#     'lifecycle:transition': 'complete'}},
#   '88': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 6, 50, 703000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1966208034', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1966208034',
#     'lifecycle:transition': 'complete'}},
#   '89': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 6, 50, 748000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1966208034', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1855507567',
#     'lifecycle:transition': 'complete'}},
#   '90': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 6, 51, 139000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1966208034', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_908904121',
#     'lifecycle:transition': 'schedule'}},
#   '91': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 8, 20, 399000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1966208034', 'User_1'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1931724944',
#     'lifecycle:transition': 'withdraw'}},
#   '92': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 8, 20, 409000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1966208034', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1828222550',
#     'lifecycle:transition': 'schedule'}},
#   '93': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 8, 20, 419000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1966208034', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_594539727',
#     'lifecycle:transition': 'complete'}},
#   '94': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 58, 26, 178000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1806387393'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1806387393',
#     'lifecycle:transition': 'complete'}},
#   '95': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 58, 26, 216000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1806387393'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_219633904',
#     'lifecycle:transition': 'complete'}},
#   '96': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 17, 58, 26, 524000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1806387393'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1241150610',
#     'lifecycle:transition': 'schedule'}},
#   '97': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 19, 13, 17, 386000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1111870538'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1111870538',
#     'lifecycle:transition': 'complete'}},
#   '98': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 19, 13, 17, 442000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1111870538'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1224473693',
#     'lifecycle:transition': 'complete'}},
#   '99': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 19, 13, 17, 750000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1111870538'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1355423985',
#     'lifecycle:transition': 'schedule'}},
#   '100': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 19, 13, 53, 205000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1111870538'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_355812133',
#     'lifecycle:transition': 'withdraw'}},
#   '101': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 19, 13, 53, 215000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1111870538'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1164338764',
#     'lifecycle:transition': 'schedule'}},
#   '102': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 19, 13, 53, 224000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1111870538'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1667592697',
#     'lifecycle:transition': 'complete'}},
#   '103': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 19, 18, 43, 997000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1017492916', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1017492916',
#     'lifecycle:transition': 'complete'}},
#   '104': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 19, 18, 44, 39000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1017492916', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1185546975',
#     'lifecycle:transition': 'complete'}},
#   '105': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 19, 18, 44, 535000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1017492916', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_717717674',
#     'lifecycle:transition': 'schedule'}},
#   '106': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 19, 19, 56, 885000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1017492916', 'User_1'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_941266706',
#     'lifecycle:transition': 'withdraw'}},
#   '107': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 19, 19, 56, 895000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1017492916', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1717295011',
#     'lifecycle:transition': 'schedule'}},
#   '108': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 19, 19, 56, 905000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1017492916', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1430393616',
#     'lifecycle:transition': 'complete'}},
#   '109': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 14, 25, 752000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_2082119944'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_2082119944',
#     'lifecycle:transition': 'complete'}},
#   '110': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 14, 25, 796000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_2082119944'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1866103021',
#     'lifecycle:transition': 'complete'}},
#   '111': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 14, 26, 166000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_2082119944'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_337408524',
#     'lifecycle:transition': 'schedule'}},
#   '112': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 16, 2, 591000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_2082119944'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_148338280',
#     'lifecycle:transition': 'withdraw'}},
#   '113': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 16, 2, 601000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_2082119944'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_582421362',
#     'lifecycle:transition': 'schedule'}},
#   '114': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 16, 2, 611000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_2082119944'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_2055923239',
#     'lifecycle:transition': 'complete'}},
#   '115': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 24, 12, 454000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_758985626'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_758985626',
#     'lifecycle:transition': 'complete'}},
#   '116': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 24, 12, 495000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_758985626'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1032886526',
#     'lifecycle:transition': 'complete'}},
#   '117': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 24, 12, 900000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_758985626'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1269145967',
#     'lifecycle:transition': 'schedule'}},
#   '118': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 25, 1, 379000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_758985626'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1230304011',
#     'lifecycle:transition': 'withdraw'}},
#   '119': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 25, 1, 389000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_758985626'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_654742586',
#     'lifecycle:transition': 'schedule'}},
#   '120': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 25, 1, 399000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_758985626'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_708360321',
#     'lifecycle:transition': 'complete'}},
#   '121': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 57, 30, 249000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1018615109'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1018615109',
#     'lifecycle:transition': 'complete'}},
#   '122': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 57, 30, 292000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1018615109'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1658343773',
#     'lifecycle:transition': 'complete'}},
#   '123': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 57, 30, 476000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1018615109'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1510422474',
#     'lifecycle:transition': 'schedule'}},
#   '124': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 58, 53, 554000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1018615109'],
#    'ocel:vmap': {'Action': 'Deleted',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1278922523',
#     'lifecycle:transition': 'withdraw'}},
#   '125': {'ocel:activity': 'W_Complete application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 58, 53, 563000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1018615109'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_916127696',
#     'lifecycle:transition': 'schedule'}},
#   '126': {'ocel:activity': 'A_Concept',
#    'ocel:timestamp': datetime.datetime(2016, 1, 1, 21, 58, 53, 572000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_1018615109'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1435115281',
#     'lifecycle:transition': 'complete'}},
#   '127': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 2, 1, 8, 49, 567000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_319587802'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_319587802',
#     'lifecycle:transition': 'complete'}},
#   '128': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 2, 1, 8, 49, 631000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_319587802'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_2095516654',
#     'lifecycle:transition': 'complete'}},
#   '129': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 2, 1, 8, 49, 839000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_319587802'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1604003555',
#     'lifecycle:transition': 'schedule'}},
#   '130': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 2, 8, 57, 1, 662000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1846626914', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_1846626914',
#     'lifecycle:transition': 'complete'}},
#   '131': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 2, 8, 57, 1, 734000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1846626914', 'User_1'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_1455015421',
#     'lifecycle:transition': 'complete'}},
#   '132': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 2, 8, 57, 2, 164000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['Application_1846626914', 'User_1'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
#     'EventID': 'Workitem_1432557025',
#     'lifecycle:transition': 'schedule'}},
#   '133': {'ocel:activity': 'A_Create Application',
#    'ocel:timestamp': datetime.datetime(2016, 1, 2, 8, 57, 3, 601000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_546206358'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Application',
#     'EventID': 'Application_546206358',
#     'lifecycle:transition': 'complete'}},
#   '134': {'ocel:activity': 'A_Submitted',
#    'ocel:timestamp': datetime.datetime(2016, 1, 2, 8, 57, 3, 637000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_546206358'],
#    'ocel:vmap': {'Action': 'statechange',
#     'EventOrigin': 'Application',
#     'EventID': 'ApplState_254307635',
#     'lifecycle:transition': 'complete'}},
#   '135': {'ocel:activity': 'W_Handle leads',
#    'ocel:timestamp': datetime.datetime(2016, 1, 2, 8, 57, 3, 828000, tzinfo=datetime.timezone.utc),
#    'ocel:omap': ['User_1', 'Application_546206358'],
#    'ocel:vmap': {'Action': 'Created',
#     'EventOrigin': 'Workflow',
# ...
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 15000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-03-01 10:32:07.797000+00:00#mail#ID['statechange', 'User_14', 'Offer', 'OfferState_252551180', 'complete', 'Offer_1419723301']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Car',
#     'case:RequestedAmount': 22200.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-04-19 10:31:31.986000+00:00#mail#ID['statechange', 'User_4', 'Offer', 'OfferState_1519866309', 'complete', 'Offer_582731852']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Existing loan takeover',
#     'case:RequestedAmount': 7500.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-12-13 12:43:08.988000+00:00#mail#ID['statechange', 'User_3', 'Offer', 'OfferState_919458765', 'complete', 'Offer_524760294']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 5350.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-11-19 14:13:06.716000+00:00#mail#ID['statechange', 'User_12', 'Offer', 'OfferState_1367018983', 'complete', 'Offer_358745230']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 10000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-09-01 07:24:38.779000+00:00#mail#ID['statechange', 'User_63', 'Offer', 'OfferState_1800318205', 'complete', 'Offer_264853109']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Existing loan takeover',
#     'case:RequestedAmount': 25000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-09-29 14:17:27.586000+00:00#mail#ID['statechange', 'User_51', 'Offer', 'OfferState_753229565', 'complete', 'Offer_1421617378']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Existing loan takeover',
#     'case:RequestedAmount': 14000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-09-30 14:23:18.522000+00:00#mail#ID['statechange', 'User_52', 'Offer', 'OfferState_2009709443', 'complete', 'Offer_1597427440']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Existing loan takeover',
#     'case:RequestedAmount': 14000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-08-16 14:03:53.070000+00:00#mail#ID['statechange', 'User_4', 'Offer', 'OfferState_1433214623', 'complete', 'Offer_1059764526']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 15000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-02-08 18:03:58.069000+00:00#mail#ID['statechange', 'User_13', 'Offer', 'OfferState_904815700', 'complete', 'Offer_1803204454']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 15000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-02-10 18:51:45.560000+00:00#mail#ID['statechange', 'User_10', 'Offer', 'OfferState_1612308714', 'complete', 'Offer_1114222863']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 15000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-01-22 18:46:21.672000+00:00#mail#ID['statechange', 'User_35', 'Offer', 'OfferState_691349564', 'complete', 'Offer_1745527822']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 25000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-01-22 18:46:21.674000+00:00#mail#ID['statechange', 'User_35', 'Offer', 'OfferState_1132723186', 'complete', 'Offer_1429639168']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 25000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-04-25 08:15:59.507000+00:00#mail#ID['statechange', 'User_46', 'Offer', 'OfferState_1734594440', 'complete', 'Offer_589599447']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 25000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-04-25 08:15:59.509000+00:00#mail#ID['statechange', 'User_46', 'Offer', 'OfferState_1384988068', 'complete', 'Offer_947646834']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 25000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-04-28 13:50:05.804000+00:00#mail#ID['statechange', 'User_46', 'Offer', 'OfferState_1942664548', 'complete', 'Offer_786978503']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 25000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-05-28 09:06:16.280000+00:00#mail#ID['statechange', 'User_5', 'Offer', 'OfferState_1714365219', 'complete', 'Offer_339807163']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 25000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-11-02 14:05:23.541000+00:00#mail#ID['statechange', 'User_50', 'Offer', 'OfferState_316795669', 'complete', 'Offer_287757624']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Unknown',
#     'case:RequestedAmount': 0.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-02-03 18:14:20.704000+00:00#mail#ID['statechange', 'User_41', 'Offer', 'OfferState_1578523439', 'complete', 'Offer_1091416222']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Car',
#     'case:RequestedAmount': 11000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-06-29 09:46:48.121000+00:00#mail#ID['statechange', 'User_15', 'Offer', 'OfferState_838917817', 'complete', 'Offer_676307998']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 8500.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-08-23 16:34:27.623000+00:00#mail#ID['statechange', 'User_33', 'Offer', 'OfferState_1735112116', 'complete', 'Offer_866629561']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Unknown',
#     'case:RequestedAmount': 0.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-05-23 07:40:07.689000+00:00#mail#ID['statechange', 'User_40', 'Offer', 'OfferState_1086611155', 'complete', 'Offer_813063301']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 40000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-05-23 07:40:07.693000+00:00#mail#ID['statechange', 'User_40', 'Offer', 'OfferState_770611753', 'complete', 'Offer_867365153']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 40000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-07-01 13:17:29.771000+00:00#mail#ID['statechange', 'User_71', 'Offer', 'OfferState_1674929512', 'complete', 'Offer_2136119406']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Unknown',
#     'case:RequestedAmount': 0.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-07-22 08:36:27.354000+00:00#mail#ID['statechange', 'User_21', 'Offer', 'OfferState_896586101', 'complete', 'Offer_622574738']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Unknown',
#     'case:RequestedAmount': 0.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-02-29 08:44:27.927000+00:00#mail#ID['statechange', 'User_35', 'Offer', 'OfferState_812067429', 'complete', 'Offer_1216209351']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Unknown',
#     'case:RequestedAmount': 0.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-08-24 09:09:57.210000+00:00#mail#ID['statechange', 'User_36', 'Offer', 'OfferState_278234732', 'complete', 'Offer_1832141493']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Car',
#     'case:RequestedAmount': 0.0,
#     'case:ApplicationType': 'Limit raise'}},
#   "2016-01-13 09:22:10.584000+00:00#mail#ID['statechange', 'User_15', 'Offer', 'OfferState_1669651112', 'complete', 'Offer_950955692']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Car',
#     'case:RequestedAmount': 14000.0,
#     'case:ApplicationType': 'Limit raise'}},
#   "2016-07-23 08:22:01.666000+00:00#mail#ID['statechange', 'User_58', 'Offer', 'OfferState_1023398657', 'complete', 'Offer_278158554']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Unknown',
#     'case:RequestedAmount': 16500.0,
#     'case:ApplicationType': 'Limit raise'}},
#   "2016-10-24 11:53:24.143000+00:00#mail#ID['statechange', 'User_36', 'Offer', 'OfferState_1664415458', 'complete', 'Offer_816178942']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 15000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-05-20 07:54:41.175000+00:00#mail#ID['statechange', 'User_53', 'Offer', 'OfferState_2121112790', 'complete', 'Offer_682728759']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 15000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-05-28 13:55:04.597000+00:00#mail#ID['statechange', 'User_76', 'Offer', 'OfferState_192775607', 'complete', 'Offer_1171023473']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 15000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-05-12 07:21:23.686000+00:00#mail#ID['statechange', 'User_41', 'Offer', 'OfferState_132221458', 'complete', 'Offer_90879260']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Caravan / Camper',
#     'case:RequestedAmount': 65000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-05-12 07:21:23.688000+00:00#mail#ID['statechange', 'User_41', 'Offer', 'OfferState_321764857', 'complete', 'Offer_1639775243']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Caravan / Camper',
#     'case:RequestedAmount': 65000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-11-07 19:13:41.154000+00:00#mail#ID['statechange', 'User_84', 'Offer', 'OfferState_2037909772', 'complete', 'Offer_537923082']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Existing loan takeover',
#     'case:RequestedAmount': 16000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-06-25 13:22:21.386000+00:00#mail#ID['statechange', 'User_85', 'Offer', 'OfferState_982434471', 'complete', 'Offer_736177535']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 5000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-01-15 18:34:27.995000+00:00#mail#ID['statechange', 'User_13', 'Offer', 'OfferState_873527227', 'complete', 'Offer_1895116381']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Car',
#     'case:RequestedAmount': 7500.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-08-31 08:34:00.448000+00:00#mail#ID['statechange', 'User_57', 'Offer', 'OfferState_1028123657', 'complete', 'Offer_139571267']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Car',
#     'case:RequestedAmount': 7500.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-09-09 10:23:53.418000+00:00#mail#ID['statechange', 'User_60', 'Offer', 'OfferState_888798473', 'complete', 'Offer_954351651']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 5000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-09-07 12:40:53.456000+00:00#mail#ID['statechange', 'User_52', 'Offer', 'OfferState_723100031', 'complete', 'Offer_313944852']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Boat',
#     'case:RequestedAmount': 15000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-12-12 11:18:20.946000+00:00#mail#ID['statechange', 'User_80', 'Offer', 'OfferState_1027243654', 'complete', 'Offer_626204982']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 5000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-12-13 08:31:58.852000+00:00#mail#ID['statechange', 'User_78', 'Offer', 'OfferState_806073099', 'complete', 'Offer_1670555919']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 5000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-01-29 19:55:11.193000+00:00#mail#ID['statechange', 'User_27', 'Offer', 'OfferState_1544789337', 'complete', 'Offer_1502996031']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 15000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-11-19 11:43:22.620000+00:00#mail#ID['statechange', 'User_39', 'Offer', 'OfferState_608181227', 'complete', 'Offer_68666768']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 26000.0,
#     'case:ApplicationType': 'Limit raise'}},
#   "2016-11-14 11:58:10.176000+00:00#mail#ID['statechange', 'User_28', 'Offer', 'OfferState_813307149', 'complete', 'Offer_1602797641']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 30000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-05-06 09:04:46.129000+00:00#mail#ID['statechange', 'User_49', 'Offer', 'OfferState_1774236', 'complete', 'Offer_415902114']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Not speficied',
#     'case:RequestedAmount': 75000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-12-21 11:39:57.294000+00:00#mail#ID['statechange', 'User_42', 'Offer', 'OfferState_308542855', 'complete', 'Offer_1596977123']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Car',
#     'case:RequestedAmount': 5000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-07-04 12:42:06.131000+00:00#mail#ID['statechange', 'User_51', 'Offer', 'OfferState_797322723', 'complete', 'Offer_1328900506']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 11500.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-04-12 19:02:18.301000+00:00#mail#ID['statechange', 'User_76', 'Offer', 'OfferState_1029503490', 'complete', 'Offer_1596158155']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 25000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-06-21 15:29:59.414000+00:00#mail#ID['statechange', 'User_35', 'Offer', 'OfferState_1665097498', 'complete', 'Offer_1228898265']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Car',
#     'case:RequestedAmount': 8000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-08-11 18:29:50.735000+00:00#mail#ID['statechange', 'User_51', 'Offer', 'OfferState_798705302', 'complete', 'Offer_1988958440']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 25000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-08-10 10:01:43.474000+00:00#mail#ID['statechange', 'User_14', 'Offer', 'OfferState_1034389704', 'complete', 'Offer_1749944468']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Other, see explanation',
#     'case:RequestedAmount': 5000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-03-18 12:53:51.816000+00:00#mail#ID['statechange', 'User_41', 'Offer', 'OfferState_710580581', 'complete', 'Offer_380086056']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Home improvement',
#     'case:RequestedAmount': 8000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-02-08 08:42:04.130000+00:00#mail#ID['statechange', 'User_35', 'Offer', 'OfferState_921991057', 'complete', 'Offer_2146174319']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Unknown',
#     'case:RequestedAmount': 15000.0,
#     'case:ApplicationType': 'New credit'}},
#   "2016-06-11 09:36:11.701000+00:00#mail#ID['statechange', 'User_17', 'Offer', 'OfferState_91251401', 'complete', 'Offer_740226034']": {'ocel:type': 'mail',
#    'ocel:ovmap': {'case:LoanGoal': 'Car',
#     'case:RequestedAmount': 7000.0,
#     'case:ApplicationType': 'New credit'}},
#   ...}}

# %%
# sample_cases
ocel_dict = {
    "ocel:global-event": {
        "ocel:activity": "__INVALID__"
    },
    "ocel:global-object": {
        "ocel:type": "__INVALID__"
    },
    "ocel:global-log": {
        "ocel:attribute-names": [

        ],
        "ocel:object-types": [

        ],
    },
    "ocel:events": {},
    "ocel:objects": {}
}
ocel_dict["ocel:global-log"]["ocel:object-types"] = ocel_log["ocel:global-log"]["ocel:object-types"]
ocel_dict["ocel:global-log"]["ocel:attribute-names"] = ocel_log["ocel:global-log"]["ocel:attribute-names"]

id_to_event = {}
referenced_objs = set()
cnt = 0
for case in sample_cases:
    current_state = "False"
    for key, event in ocel_log["ocel:events"].items():
        if case not in event["ocel:omap"]:
            continue
        #print(type(event))
        event["ocel:vmap"] = dict(event["ocel:vmap"])
        #print(type(event["ocel:vmap"]))
        if "Accepted" in event["ocel:vmap"] and event["ocel:vmap"]["Accepted"] == "true":
            current_state = "True"
        event["ocel:vmap"]["OfferAccepted"] = current_state
    referenced_objs.update(event["ocel:omap"])
    id_to_event[key] = event
    cnt += 1
    if cnt % 100 == 0:
        print("done with", cnt, "cases")

from collections import OrderedDict
id_to_event = OrderedDict(sorted(id_to_event.items()))
objs_dict = {key: obj for key, obj in ocel_log["ocel:objects"].items() if key in referenced_objs}

ocel_dict["ocel:events"] = dict(id_to_event)
ocel_dict["ocel:objects"] = objs_dict
# Out:
# done with 100 cases
# done with 200 cases
# done with 300 cases
# done with 400 cases
# done with 500 cases
# done with 600 cases
# done with 700 cases
# done with 800 cases
# done with 900 cases
# done with 1000 cases

# %%
ocel.export_log(ocel_dict, "BPI_2017_altered.jsonocel")

# %%
print(id_to_event)
# Out:
# OrderedDict([('1202267', {'ocel:activity': 'W_Validate application', 'ocel:timestamp': datetime.datetime(2017, 2, 1, 14, 11, 3, 499000, tzinfo=datetime.timezone.utc), 'ocel:omap': ['User_100', 'Application_586083090'], 'ocel:vmap': {'Action': 'Released', 'EventOrigin': 'Workflow', 'EventID': 'Workitem_1026890863', 'lifecycle:transition': 'suspend'}})])
