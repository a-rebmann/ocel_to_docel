# %%
pip install names
# Out:
# Requirement already satisfied: names in /Users/adrianrebmann/anaconda3/lib/python3.9/site-packages (0.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas==1.5.1
# Out:
# Requirement already satisfied: pandas==1.5.1 in /Users/adrianrebmann/anaconda3/lib/python3.9/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.20.3 in /Users/adrianrebmann/anaconda3/lib/python3.9/site-packages (from pandas==1.5.1) (1.24.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/adrianrebmann/anaconda3/lib/python3.9/site-packages (from pandas==1.5.1) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/adrianrebmann/anaconda3/lib/python3.9/site-packages (from pandas==1.5.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/adrianrebmann/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas==1.5.1) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import names
import random
import time
from datetime import datetime
import numpy as np
from random import randrange
from datetime import timedelta

# %%
#To generate initial timestamps

def random_date(start, end):
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    return start + timedelta(seconds=random_second)

# %% [markdown]
# Create product table

# %%
# initialize data of lists.
product_types = {'PID': ['P1', 'P2', 'P3'],
        'Value': [15,10,20],
         'Fragile': [0,0,1]}

# Create DataFrame
product_types_df = pd.DataFrame(product_types)

# Print the output.
product_types_df
# Out:
#   PID  Value  Fragile
# 0  P1     15        0
# 1  P2     10        0
# 2  P3     20        1

# %% [markdown]
# Create customer table

# %%
customers_df = pd.DataFrame(columns = ["CID", "Name","Bank Account"])
for i in range(50):
    customers_df = customers_df.append({'CID':"c"+str(i+1),
                                        'Name':names.get_full_name(),
                                        'Bank Account': 'BE'+ str(68-i)+" " + str(7689-i*3)+" "  + str(4567+i*13+67)+" "  + str(3467 - i*7 -789)},
                                       ignore_index=True)
customers_df
# Out:
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/3148138654.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
#     CID               Name         Bank Account
# 0    c1         Edgar Rapp  BE68 7689 4634 2678
# 1    c2         James Dinh  BE67 7686 4647 2671
# 2    c3        Emily Hudek  BE66 7683 4660 2664
# 3    c4      Judith Duenas  BE65 7680 4673 2657
# 4    c5  Gabriel Livengood  BE64 7677 4686 2650
# 5    c6         Mindy Edge  BE63 7674 4699 2643
# 6    c7          Joyce Lee  BE62 7671 4712 2636
# 7    c8        Deena Avila  BE61 7668 4725 2629
# 8    c9    Margaret Hanson  BE60 7665 4738 2622
# 9   c10    Barbara Johnson  BE59 7662 4751 2615
# 10  c11    Jessica Estrada  BE58 7659 4764 2608
# 11  c12    Carla Fairfield  BE57 7656 4777 2601
# 12  c13      Andrew Talbot  BE56 7653 4790 2594
# 13  c14    Patricia Wrubel  BE55 7650 4803 2587
# 14  c15     Phillip Brooks  BE54 7647 4816 2580
# 15  c16    Morris Langston  BE53 7644 4829 2573
# 16  c17          Sara Vega  BE52 7641 4842 2566
# 17  c18       Odessa Lopez  BE51 7638 4855 2559
# 18  c19   Alfonso Winstead  BE50 7635 4868 2552
# 19  c20      Barbara Smith  BE49 7632 4881 2545
# 20  c21        Donna Nolte  BE48 7629 4894 2538
# 21  c22      Robert Baccam  BE47 7626 4907 2531
# 22  c23       Lane Jenkins  BE46 7623 4920 2524
# 23  c24        Kate Gainer  BE45 7620 4933 2517
# 24  c25          Arthur Vu  BE44 7617 4946 2510
# 25  c26    Dorothy Collins  BE43 7614 4959 2503
# 26  c27      Ursula Graber  BE42 7611 4972 2496
# 27  c28        Elroy Lyons  BE41 7608 4985 2489
# 28  c29     Clinton Taylor  BE40 7605 4998 2482
# 29  c30       Angela Reyes  BE39 7602 5011 2475
# 30  c31        Alia Rafter  BE38 7599 5024 2468
# 31  c32      Javier Emmick  BE37 7596 5037 2461
# 32  c33       Dennis Canup  BE36 7593 5050 2454
# 33  c34       Danny Tockey  BE35 7590 5063 2447
# 34  c35   Edward Patterson  BE34 7587 5076 2440
# 35  c36     Elizabeth Prow  BE33 7584 5089 2433
# 36  c37   Jeffrey Gallahan  BE32 7581 5102 2426
# 37  c38       James Pettit  BE31 7578 5115 2419
# 38  c39    Willie Brookins  BE30 7575 5128 2412
# 39  c40   Melinda Demarais  BE29 7572 5141 2405
# 40  c41     Marie Martinez  BE28 7569 5154 2398
# 41  c42      Richard Hanus  BE27 7566 5167 2391
# 42  c43      Dawn Marchant  BE26 7563 5180 2384
# 43  c44    William Goodrow  BE25 7560 5193 2377
# 44  c45   Consuelo Webster  BE24 7557 5206 2370
# 45  c46   Tracey Ratcliffe  BE23 7554 5219 2363
# 46  c47         Grace Wood  BE22 7551 5232 2356
# 47  c48       Susan Lipsky  BE21 7548 5245 2349
# 48  c49       Joyce Deluca  BE20 7545 5258 2342
# 49  c50        Craig Brown  BE19 7542 5271 2335

# %% [markdown]
# Create Order table

# %%
orders_df = pd.DataFrame(columns = ["OID","Quantity"])

# %% [markdown]
# Create the events table and the dynamic attribute tables

# %%
events_df = pd.DataFrame(columns = ["EID", "Activity","Timestamp",'Customer','Order',"Product Type","Resource"])
quantity_df = pd.DataFrame(columns = ["QID", "P1","P2",'P3',"EID","OID"])
order_value_df = pd.DataFrame(columns = ["VID", "Value","EID","OID"])
refund_df = pd.DataFrame(columns = ["RID", "Refund Value","EID","OID"])
shipping_method_df = pd.DataFrame(columns = ["SID", "Method","EID","OID"])

# %% [markdown]
# Create list of potential resources for each activity

# %%
#Resources1 are responsible for the activities: Receive order, confirm purchase, determine shipping method,
#sent invoice, recollect letter, pay refund, file order

Resources1= ['Jan','Gabriel','Olivia','Sophia','Evelyn','Noah']

#Resources 2 are responsible for the activities: Collect product, put protection around product, add product to package

Resources2 = ['Johannes','Elizabeth','Jack','Chloe','Sebastian','Grace']

#Resources 3 are responsible for the activities: Ship by courrier, Ship by mail, ship by express courrier, deliver package

Resources3 = ['Alexandre','Violet','David','Zoe','Ryan','Claire']

# %%
def choice_excluding(lst, exception):
    possible_choices = [v for v in lst if v != exception]
    return random.choice(possible_choices)
print(choice_excluding(Resources1,random.choice(Resources1)))
# Out:
# Evelyn

# %% [markdown]
# Create first event

# %%
#Spare  with the idea of having the timestamps overlap
count = 1
Number_of_orders=10

resource1 = random.choice(Resources1)
resource2 = random.choice(Resources2)
resource3 = random.choice(Resources3)

start = datetime.strptime('1/1/2022 08:30 AM', '%d/%m/%Y %I:%M %p')
end =  datetime.strptime('1/1/2022 6:00 PM', '%d/%m/%Y %I:%M %p')

for i in range(0, Number_of_orders):
    #Initialize customers
    customer= customers_df.sample()
    CID=customer['CID'].values
    #Initialize products
    product = product_types_df.sample(n=3,replace=True)
    product_list = set(product.PID.values.tolist())
    print('product_list', product_list)

    #Initialize resources
    resource1 = choice_excluding(Resources1,resource1)
    resource2 = choice_excluding(Resources2,resource2)
    resource3 = choice_excluding(Resources3,resource3)

    print(start,end)

    stamp = random_date(start, end)

# Create first event

    #Events Table
    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Place Order',
                                    'Timestamp': stamp,
                                 'Customer': CID[0],
                                 'Order': 'o'+str(i+1),
                                 'Product Type': product_list},
                                           ignore_index=True)
    # Order Table
    orders_df=orders_df.append({'OID':'o'+str(i+1)},ignore_index=True)
    # Quantity Table
    quantity_df = quantity_df.append({'QID': 'Q' + str(i+1),'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
    total = 0
    Quantity = []
    for q in range(0,3):
            quantity = random.randint(1, 4)
            Quantity.append(quantity)
            value = product.iloc[q]['Value']*quantity
            total = total + value
    product['Quantity'] = Quantity
    q_sum = product.groupby('PID').sum()
    print(q_sum)


    for value in product_list:
        quantity_df.at[i,value] = q_sum.at[value,'Quantity']


    # Refund Table
    refund_df = refund_df.append({'RID':'R'+ str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)

    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)



 # Create event 2

    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Receive Order',
                                    'Timestamp': stamp,
                                 'Customer': CID[0],
                                 'Order': 'o'+str(i+1),
                                 'Product Type': product_list,
                                 'Resource': resource1},
                                           ignore_index=True)
    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

 # Create event 3

    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Confirm Purchase',
                                    'Timestamp': stamp,

                                 'Order': 'o'+str(i+1),
                                 'Product Type': product_list,
                                 'Resource': resource1},
                                           ignore_index=True)

    # Value Table (created by confirm purchase)

    order_value_df = order_value_df.append({'VID':'V'+str(i+1),'Value': total,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)

    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

 # Create event 4
    for value in product_list:
        events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Collect product from warehouse',
                                    'Timestamp': stamp,

                                 'Order': 'o'+str(i+1),
                                 'Product Type': set([value]),
                                 'Resource': resource2},
                                           ignore_index=True)
        # Increase count
        count = count + 1

       #Increase timestamp at random between 1 and 700 seconds
        time_duration = random.uniform(1,700)

        stamp = stamp + timedelta(seconds=time_duration)

 # Create event 5
    for value in product_list:
        fragile = product_types_df.loc[product_types_df['PID'] == value]['Fragile'].values
        if fragile[0] == 1:
            events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Put protection around the product',
                                    'Timestamp': stamp,

                                 'Order': 'o'+str(i+1),
                                 'Product Type': set([value]),
                                 'Resource': resource2},
                                           ignore_index=True)
            # Increase count
            count = count + 1

            #Increase timestamp at random between 1 and 700 seconds
            time_duration = random.uniform(1,700)

            stamp = stamp + timedelta(seconds=time_duration)

 # Create event 6
    for value in product_list:
        events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Add product to package',
                                    'Timestamp':  stamp,

                                 'Order': 'o'+str(i+1),
                                 'Product Type': set([value]),
                                 'Resource': resource2},
                                           ignore_index=True)
        # Increase count
        count = count + 1

        #Increase timestamp at random between 1 and 700 seconds
        time_duration = random.uniform(1,700)

        stamp = stamp + timedelta(seconds=time_duration)

# Create event 7
    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Get confirmation',
                                  'Timestamp': stamp,
                                 'Customer': CID[0],
                                 'Order': 'o'+str(i+1)},
                                           ignore_index=True)
    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

# Create event 8
    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Confirm shipping information',
                                  'Timestamp': stamp,
                                 'Customer': CID[0],
                                 'Order': 'o'+str(i+1)},
                                           ignore_index=True)
    # Increase count
    count = count + 1

   #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

# Create event 9
    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Determine shipping method',
                                  'Timestamp': stamp,
                                 'Product Type': product_list,
                                 'Order': 'o'+str(i+1),
                                 'Resource': resource1},
                                           ignore_index=True)
   # Increase count
    count = count + 1

   #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

    #make the shipping method table

    #We need to parallelize therefore we make a split with random so either first the courrier is
    #send or first the invoice is send
    split = random.randint(0, 1)

    #Shipping method comes first

    if split==1:
        print('Shipping method comes first')
        #make event Determine shipping method and shipping method event itself
        control=0
        for value in product_list:
            fragile = product_types_df.loc[product_types_df['PID'] == value]['Fragile'].values
            if fragile[0] == 1:
                control = 1
                shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-1),
                                                        'SID': 'S'+str(shipping_method_df.shape[0] + 1),
                                                        'Method': 'Courrier',
                                                        'OID':'o' + str(i+1)},
                                               ignore_index=True)

                #Add shipping event courrier

                now=datetime.now()
                events_df = events_df.append({'EID':"e"+str(i+count),
                                      'Activity':'Ship by courrier',
                                      'Timestamp': stamp,

                                     'Order': 'o'+str(i+1),
                                     'Resource': resource3},
                                               ignore_index=True)
                # Increase count
                count = count + 1

                #Increase timestamp at random between 1 and 700 seconds
                time_duration = random.uniform(1,700)

                stamp = stamp + timedelta(seconds=time_duration)

                break

        if order_value_df.loc[i]['Value'] >= 100 and control !=1 :
            control = 1
            shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-1),
                                                        'SID': 'S' + str(shipping_method_df.shape[0] + 1),
                                                        'Method': 'Courrier',
                                                        'OID':'o' + str(i+1)},
                                                   ignore_index=True)
            #Add shipping event courrier
            now=datetime.now()
            events_df = events_df.append({'EID':"e"+str(i+count),
                                      'Activity':'Ship by courrier',
                                      'Timestamp': stamp,

                                     'Order': 'o'+str(i+1),
                                                         'Resource': resource3},
                                               ignore_index=True)
            # Increase count
            count = count + 1

            #Increase timestamp at random between 1 and 700 seconds
            time_duration = random.uniform(1,700)

            stamp = stamp + timedelta(seconds=time_duration)

        if control !=1:
            shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-1),
                                                        'SID': 'S'+str(shipping_method_df.shape[0] + 1),
                                                        'Method': 'Mail',
                                                        'OID':'o' + str(i+1)},
                                                   ignore_index=True)
            #Add shipping event mail
            events_df = events_df.append({'EID':"e"+str(i+count),
                                      'Activity':'Ship by mail',
                                      'Timestamp': stamp,
                                     'Order': 'o'+str(i+1),
                                                         'Resource': resource3},
                                               ignore_index=True)
            # Increase count
            count = count + 1

            #Increase timestamp at random between 1 and 700 seconds
            time_duration = random.uniform(1,700)

            stamp = stamp + timedelta(seconds=time_duration)

        # Create event send invoice
        events_df = events_df.append({'EID':"e"+str(i+count),
                                      'Activity':'Send invoice',
                                      'Timestamp': stamp,
                                     'Order': 'o'+str(i+1),
                                     'Resource': resource1},
                                               ignore_index=True)
        # Increase count
        count = count + 1

        #Increase timestamp at random between 1 and 700 seconds
        time_duration = random.uniform(1,700)

        stamp = stamp + timedelta(seconds=time_duration)

    #Sent invoice comes first

    if split==0:
        print('Send invoice comes first')
         # Create event send invoice
        events_df = events_df.append({'EID':"e"+str(i+count),
                                      'Activity':'Send invoice',
                                      'Timestamp': stamp,
                                     'Order': 'o'+str(i+1),
                                     'Resource': resource1},
                                               ignore_index=True)
        # Increase count
        count = count + 1

        #Increase timestamp at random between 1 and 700 seconds
        time_duration = random.uniform(1,700)

        stamp = stamp + timedelta(seconds=time_duration)

        #make event Determine shipping method and shipping method event itself
        control=0
        for value in product_list:
            fragile = product_types_df.loc[product_types_df['PID'] == value]['Fragile'].values
            if fragile[0] == 1:
                control = 1
                shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-2),
                                                        'SID': 'S'+str(shipping_method_df.shape[0] + 1),
                                                        'Method': 'Courrier',
                                                        'OID':'o' + str(i+1)},
                                               ignore_index=True)

                #Add shipping event courrier

                now=datetime.now()
                events_df = events_df.append({'EID':"e"+str(i+count),
                                      'Activity':'Ship by courrier',
                                      'Timestamp': stamp,

                                     'Order': 'o'+str(i+1),
                                     'Resource': resource3},
                                               ignore_index=True)
                # Increase count
                count = count + 1

               #Increase timestamp at random between 1 and 700 seconds
                time_duration = random.uniform(1,700)

                stamp = stamp + timedelta(seconds=time_duration)

                break

        if order_value_df.loc[i]['Value'] >= 100 and control !=1 :
            control = 1
            shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-2),
                                                        'SID': 'S' + str(shipping_method_df.shape[0] + 1),
                                                        'Method': 'Courrier',
                                                        'OID':'o' + str(i+1)},
                                                   ignore_index=True)
            #Add shipping event courrier
            now=datetime.now()
            events_df = events_df.append({'EID':"e"+str(i+count),
                                      'Activity':'Ship by courrier',
                                      'Timestamp': stamp,

                                     'Order': 'o'+str(i+1),
                                                         'Resource': resource3},
                                               ignore_index=True)
            # Increase count
            count = count + 1

           #Increase timestamp at random between 1 and 700 seconds
            time_duration = random.uniform(1,700)

            stamp = stamp + timedelta(seconds=time_duration)

        if control !=1:
            shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-2),
                                                        'SID': 'S'+str(shipping_method_df.shape[0] + 1),
                                                        'Method': 'Mail',
                                                        'OID':'o' + str(i+1)},
                                                   ignore_index=True)
            #Add shipping event mail
            now=datetime.now()
            events_df = events_df.append({'EID':"e"+str(i+count),
                                      'Activity':'Ship by mail',
                                      'Timestamp': stamp,
                                     'Order': 'o'+str(i+1),
                                                         'Resource': resource3},
                                               ignore_index=True)
            # Increase count
            count = count + 1


            #Increase timestamp at random between 1 and 700 seconds
            time_duration = random.uniform(1,700)

            stamp = stamp + timedelta(seconds=time_duration)

    # Create event deliver package
    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Deliver package',
                                  'Timestamp': stamp ,
                                 'Order': 'o'+str(i+1),
                                 'Customer':CID[0],
                                                     'Resource': resource3},
                                           ignore_index=True)

    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

    # Create event Determine satisfaction
        #randomly decide on whether the customer wants a refund or not
    r = random.randint(0, 1)

    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Determine satisfaction',
                                  'Timestamp': stamp ,
                                 'Order': 'o'+str(i+1),
                                 'Customer':CID[0]},
                                           ignore_index=True)
    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

    if r==0:
        print('Customer does not want refund')
        count = count + 1
        events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'File Order',
                                  'Timestamp': stamp ,
                                 'Order': 'o'+str(i+1),
                                 'Resource': resource1
                                 },
                                           ignore_index=True)


        #Initialize the next timerange
        start = stamp - timedelta(seconds=10000)
        end = stamp

        continue

    #if no refund is asked the process ends with file order

    #create event File order
    else:
        refund_df = refund_df.append({'RID':'R' + str(refund_df.shape[0] + 1), 'Refund Value' : 1,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)

        print('Since refund is asked, we take the other path')

     # Increase count
    count = count + 1

   #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

    # Create event Request refund


    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Request refund',
                                  'Timestamp': stamp ,
                                 'Order': 'o'+str(i+1),
                                 'Customer':CID[0]},
                                           ignore_index=True)


    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

    # Create event Confirm shipping information

    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Confirm shipping information',
                                  'Timestamp': stamp ,
                                 'Order': 'o'+str(i+1),
                                 'Customer':CID[0]},
                                           ignore_index=True)

    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

    # Create event Determine shipping method

    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Determine shipping method',
                                  'Timestamp': stamp ,
                                 'Order': 'o'+str(i+1),
                                 'Resource': resource1},
                                           ignore_index=True)


    shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count),
                                                    'SID': 'S'+ str(shipping_method_df.shape[0] + 1),
                                                    'Method': 'Express Courrier',
                                                    'OID':'o' + str(i+1)},
                                               ignore_index=True)

   # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)


    #We need to parallelize therefore we make a split with random so either first the express courrier is
    #send or first the recollect letter is send

    split = random.randint(0, 1)

    if split == 0:
            print('first express courrier then recollect letter')

            # Create event Ship by express courrier

            events_df = events_df.append({'EID':"e"+str(i+count),
                                          'Activity':'Ship by express courrier',
                                          'Timestamp': stamp ,
                                         'Order': 'o'+str(i+1),
                                                             'Resource': resource3},
                                                   ignore_index=True)




            # Increase count
            count = count + 1

            #Increase timestamp at random between 1 and 700 seconds
            time_duration = random.uniform(1,700)

            stamp = stamp + timedelta(seconds=time_duration)

            # Create event Recollect Letter

            events_df = events_df.append({'EID':"e"+str(i+count),
                                          'Activity':'Recollect Letter',
                                          'Timestamp': stamp ,
                                         'Order': 'o'+str(i+1),
                                         'Resource': resource1},
                                                   ignore_index=True)


            # Increase count
            count = count + 1

            #Increase timestamp at random between 1 and 700 seconds
            time_duration = random.uniform(1,700)

            stamp = stamp + timedelta(seconds=time_duration)

    if split == 1:
        print('first recollect letter then express courrier')

         # Create event Recollect Letter

        events_df = events_df.append({'EID':"e"+str(i+count),
                                      'Activity':'Recollect Letter',
                                      'Timestamp': stamp ,
                                     'Order': 'o'+str(i+1),
                                     'Resource': resource1},
                                               ignore_index=True)


        # Increase count
        count = count + 1

        #Increase timestamp at random between 1 and 700 seconds
        time_duration = random.uniform(1,700)

        stamp = stamp + timedelta(seconds=time_duration)

        # Create event Ship by express courrier

        events_df = events_df.append({'EID':"e"+str(i+count),
                                      'Activity':'Ship by express courrier',
                                      'Timestamp': stamp ,
                                     'Order': 'o'+str(i+1),
                                                         'Resource': resource3},
                                               ignore_index=True)

        # Increase count
        count = count + 1

        #Increase timestamp at random between 1 and 700 seconds
        time_duration = random.uniform(1,700)

        stamp = stamp + timedelta(seconds=time_duration)



    # Create event Return Package

    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Return Package',
                                  'Timestamp': stamp ,
                                 'Order': 'o'+str(i+1),
                                 'Customer': CID[0]},
                                           ignore_index=True)


    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

     # Create event Pay refund

    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Pay refund',
                                  'Timestamp': stamp ,
                                 'Order': 'o'+str(i+1),
                                 'Customer': CID[0],
                                 'Resource': resource1},
                                           ignore_index=True)


    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

    # Create event Deliver package

    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Deliver package',
                                  'Timestamp': stamp ,
                                 'Order': 'o'+str(i+1),
                                 'Customer': CID[0],
                                                     'Resource': resource3},
                                           ignore_index=True)


    # Increase count
    count = count + 1

   #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

    #Create event Determine satisfaction

    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Determine satisfaction',
                                  'Timestamp': stamp ,
                                 'Order': 'o'+str(i+1),
                                 'Customer':CID[0]},
                                           ignore_index=True)

    #Change refund variable to 0 since the customer is happy

    refund_df = refund_df.append({'RID':'R' + str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)


   # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,700)

    stamp = stamp + timedelta(seconds=time_duration)

    #Create event File Order

    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'File Order',
                                  'Timestamp': stamp ,
                                 'Order': 'o'+str(i+1),
                                 'Resource': resource1},
                                           ignore_index=True)


    #Initialize the next timerange
    start = stamp- timedelta(seconds=10000)
    end = stamp
# Out:
# product_list {'P3', 'P1'}
# 2022-01-01 08:30:00 2022-01-01 18:00:00
#      Value  Fragile  Quantity
# PID
# P1      15        0         3
# P3      40        2         6
# Shipping method comes first
# Customer does not want refund
# product_list {'P2', 'P1'}
# 2022-01-01 07:35:05.276853 2022-01-01 10:21:45.276853
#      Value  Fragile  Quantity
# PID
# P1      15        0         4
# P2      20        0         3
# Send invoice comes first
# Customer does not want refund
# product_list {'P3', 'P1'}
# 2022-01-01 06:57:42.393784 2022-01-01 09:44:22.393784
#      Value  Fragile  Quantity
# PID
# P1      30        0         7
# P3      20        1         1
# Send invoice comes first
# Customer does not want refund
# product_list {'P3', 'P1'}
# 2022-01-01 07:59:08.523535 2022-01-01 10:45:48.523535
#      Value  Fragile  Quantity
# PID
# P1      30        0         3
# P3      20        1         2
# Send invoice comes first
# Customer does not want refund
# product_list {'P3', 'P2'}
# 2022-01-01 08:52:47.888922 2022-01-01 11:39:27.888922
#      Value  Fragile  Quantity
# PID
# P2      20        0         7
# P3      20        1         4
# Send invoice comes first
# Since refund is asked, we take the other path
# first express courrier then recollect letter
# product_list {'P3', 'P2'}
# 2022-01-01 09:52:58.462924 2022-01-01 12:39:38.462924
#      Value  Fragile  Quantity
# PID
# P2      10        0         3
# P3      40        2         6
# Send invoice comes first
# Customer does not want refund
# product_list {'P3', 'P1'}
# 2022-01-01 10:17:10.585188 2022-01-01 13:03:50.585188
#      Value  Fragile  Quantity
# PID
# P1      15        0         3
# P3      40        2         3
# Shipping method comes first
# Since refund is asked, we take the other path
# first express courrier then recollect letter
# product_list {'P3', 'P1', 'P2'}
# 2022-01-01 12:25:24.357141 2022-01-01 15:12:04.357141
#      Value  Fragile  Quantity
# PID
# P1      15        0         3
# P2      10        0         3
# P3      20        1         2
# Send invoice comes first
# Since refund is asked, we take the other path
# first recollect letter then express courrier
# product_list {'P2', 'P1'}
# 2022-01-01 12:09:42.203578 2022-01-01 14:56:22.203578
#      Value  Fragile  Quantity
# PID
# P1      30        0         2
# P2      10        0         3
# Send invoice comes first
# Customer does not want refund
# product_list {'P2'}
# 2022-01-01 11:05:49.635744 2022-01-01 13:52:29.635744
#      Value  Fragile  Quantity
# PID
# P2      30        0        10
# Send invoice comes first
# Customer does not want refund
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df=orders_df.append({'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   quantity_df = quantity_df.append({'QID': 'Q' + str(i+1),'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R'+ str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:104: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_value_df = order_value_df.append({'VID':'V'+str(i+1),'Value': total,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:186: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:201: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:232: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:241: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:304: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:417: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:437: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:451: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df=orders_df.append({'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   quantity_df = quantity_df.append({'QID': 'Q' + str(i+1),'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R'+ str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:104: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_value_df = order_value_df.append({'VID':'V'+str(i+1),'Value': total,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:186: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:201: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:323: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:394: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-2),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:401: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:417: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:437: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:451: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df=orders_df.append({'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   quantity_df = quantity_df.append({'QID': 'Q' + str(i+1),'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R'+ str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:104: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_value_df = order_value_df.append({'VID':'V'+str(i+1),'Value': total,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:186: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:201: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:323: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:343: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-2),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:352: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:417: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:437: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:451: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df=orders_df.append({'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   quantity_df = quantity_df.append({'QID': 'Q' + str(i+1),'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R'+ str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:104: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_value_df = order_value_df.append({'VID':'V'+str(i+1),'Value': total,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:186: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:201: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:323: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:343: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-2),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:352: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:417: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:437: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:451: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df=orders_df.append({'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   quantity_df = quantity_df.append({'QID': 'Q' + str(i+1),'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R'+ str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:104: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_value_df = order_value_df.append({'VID':'V'+str(i+1),'Value': total,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:186: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:201: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:323: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:343: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-2),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:352: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:417: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:437: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:470: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R' + str(refund_df.shape[0] + 1), 'Refund Value' : 1,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:485: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:503: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:520: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:553: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:573: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:631: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:649: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:668: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:687: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:696: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R' + str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:709: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df=orders_df.append({'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   quantity_df = quantity_df.append({'QID': 'Q' + str(i+1),'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R'+ str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:104: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_value_df = order_value_df.append({'VID':'V'+str(i+1),'Value': total,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:186: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:201: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:323: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:343: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-2),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:352: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:417: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:437: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:451: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df=orders_df.append({'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   quantity_df = quantity_df.append({'QID': 'Q' + str(i+1),'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R'+ str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:104: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_value_df = order_value_df.append({'VID':'V'+str(i+1),'Value': total,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:186: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:201: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:232: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-1),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:241: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:304: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:417: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:437: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:470: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:343: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-2),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:352: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:417: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:437: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:470: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R' + str(refund_df.shape[0] + 1), 'Refund Value' : 1,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:485: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:503: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:520: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:528: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:594: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:612: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:631: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:649: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:668: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:687: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:696: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R' + str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:709: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df=orders_df.append({'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   quantity_df = quantity_df.append({'QID': 'Q' + str(i+1),'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R'+ str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:104: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_value_df = order_value_df.append({'VID':'V'+str(i+1),'Value': total,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:186: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:201: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:323: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:394: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-2),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:401: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:417: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:437: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:451: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df=orders_df.append({'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   quantity_df = quantity_df.append({'QID': 'Q' + str(i+1),'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:61: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refund_df = refund_df.append({'RID':'R'+ str(refund_df.shape[0] + 1), 'Refund Value' : 0,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:93: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:104: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_value_df = order_value_df.append({'VID':'V'+str(i+1),'Value': total,'EID':"e"+str(i+count),'OID':'o'+str(i+1)},ignore_index=True)
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:116: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:186: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:201: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:323: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   shipping_method_df = shipping_method_df.append({'EID':"e"+str(i+count-2),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:378: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:417: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:437: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1366330266.py:451: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),

# %% [markdown]
# Order the events by timestamps

# %%
#First order events by timestamps
events_df = pd.DataFrame(events_df)
events_df = events_df.sort_values(by=['Timestamp'])
#Reset the indexes
events_df= events_df.reset_index(drop=True)
events_df= events_df.reset_index()
#Rename column names
events_df=events_df.rename(columns = {'index':'EID_new', 'EID':'EID_old'})
#Rename the values of 'EID_new'
events_df['EID_new'] ='e' + events_df['EID_new'].astype(str)
events_df.head(50)
# Out:
#    EID_new EID_old                           Activity  \
# 0       e0     e17                        Place Order
# 1       e1     e18                      Receive Order
# 2       e2     e32                        Place Order
# 3       e3     e19                   Confirm Purchase
# 4       e4     e20     Collect product from warehouse
# 5       e5     e21     Collect product from warehouse
# 6       e6     e33                      Receive Order
# 7       e7     e22             Add product to package
# 8       e8      e1                        Place Order
# 9       e9      e2                      Receive Order
# 10     e10      e3                   Confirm Purchase
# 11     e11     e23             Add product to package
# 12     e12     e24                   Get confirmation
# 13     e13     e34                   Confirm Purchase
# 14     e14     e25       Confirm shipping information
# 15     e15     e26          Determine shipping method
# 16     e16      e4     Collect product from warehouse
# 17     e17     e35     Collect product from warehouse
# 18     e18     e27                       Send invoice
# 19     e19     e28                       Ship by mail
# 20     e20      e5     Collect product from warehouse
# 21     e21     e36     Collect product from warehouse
# 22     e22     e29                    Deliver package
# 23     e23      e6  Put protection around the product
# 24     e24     e37  Put protection around the product
# 25     e25      e7             Add product to package
# 26     e26     e30             Determine satisfaction
# 27     e27     e38             Add product to package
# 28     e28      e8             Add product to package
# 29     e29     e31                         File Order
# 30     e30     e39             Add product to package
# 31     e31      e9                   Get confirmation
# 32     e32     e10       Confirm shipping information
# 33     e33     e40                   Get confirmation
# 34     e34     e11          Determine shipping method
# 35     e35     e12                   Ship by courrier
# 36     e36     e13                       Send invoice
# 37     e37     e41       Confirm shipping information
# 38     e38     e14                    Deliver package
# 39     e39     e48                        Place Order
# 40     e40     e49                      Receive Order
# 41     e41     e15             Determine satisfaction
# 42     e42     e42          Determine shipping method
# 43     e43     e50                   Confirm Purchase
# 44     e44     e16                         File Order
# 45     e45     e43                       Send invoice
# 46     e46     e44                   Ship by courrier
# 47     e47     e51     Collect product from warehouse
# 48     e48     e64                        Place Order
# 49     e49     e45                    Deliver package
#
#                     Timestamp Customer Order Product Type   Resource
# 0  2022-01-01 08:32:46.276853      c26    o2     {P2, P1}        NaN
# 1  2022-01-01 08:42:16.780357      c26    o2     {P2, P1}     Evelyn
# 2  2022-01-01 08:43:59.393784      c26    o3     {P3, P1}        NaN
# 3  2022-01-01 08:44:09.469830      NaN    o2     {P2, P1}     Evelyn
# 4  2022-01-01 08:45:11.063350      NaN    o2         {P2}      Chloe
# 5  2022-01-01 08:53:35.611360      NaN    o2         {P1}      Chloe
# 6  2022-01-01 08:54:33.187220      c26    o3     {P3, P1}    Gabriel
# 7  2022-01-01 08:58:57.904176      NaN    o2         {P2}      Chloe
# 8  2022-01-01 08:59:06.000000       c9    o1     {P3, P1}        NaN
# 9  2022-01-01 08:59:09.935661       c9    o1     {P3, P1}     Sophia
# 10 2022-01-01 08:59:12.037048      NaN    o1     {P3, P1}     Sophia
# 11 2022-01-01 08:59:49.781638      NaN    o2         {P1}      Chloe
# 12 2022-01-01 09:00:41.054161      c26    o2          NaN        NaN
# 13 2022-01-01 09:01:35.841459      NaN    o3     {P3, P1}    Gabriel
# 14 2022-01-01 09:02:04.364303      c26    o2          NaN        NaN
# 15 2022-01-01 09:06:21.690416      NaN    o2     {P2, P1}     Evelyn
# 16 2022-01-01 09:06:39.250839      NaN    o1         {P3}       Jack
# 17 2022-01-01 09:12:23.919257      NaN    o3         {P3}      Grace
# 18 2022-01-01 09:13:12.495386      NaN    o2          NaN     Evelyn
# 19 2022-01-01 09:15:42.574143      NaN    o2          NaN      David
# 20 2022-01-01 09:16:01.864477      NaN    o1         {P1}       Jack
# 21 2022-01-01 09:18:52.554492      NaN    o3         {P1}      Grace
# 22 2022-01-01 09:22:58.037186      c26    o2          NaN      David
# 23 2022-01-01 09:24:30.767323      NaN    o1         {P3}       Jack
# 24 2022-01-01 09:30:18.610220      NaN    o3         {P3}      Grace
# 25 2022-01-01 09:30:26.582117      NaN    o1         {P3}       Jack
# 26 2022-01-01 09:34:10.024252      c26    o2          NaN        NaN
# 27 2022-01-01 09:38:48.816367      NaN    o3         {P3}      Grace
# 28 2022-01-01 09:39:06.211227      NaN    o1         {P1}       Jack
# 29 2022-01-01 09:44:22.393784      NaN    o2          NaN     Evelyn
# 30 2022-01-01 09:44:25.402331      NaN    o3         {P1}      Grace
# 31 2022-01-01 09:48:00.836854       c9    o1          NaN        NaN
# 32 2022-01-01 09:54:42.521112       c9    o1          NaN        NaN
# 33 2022-01-01 09:56:01.747915      c26    o3          NaN        NaN
# 34 2022-01-01 09:56:23.233046      NaN    o1     {P3, P1}     Sophia
# 35 2022-01-01 10:06:23.770660      NaN    o1          NaN  Alexandre
# 36 2022-01-01 10:06:45.300650      NaN    o1          NaN     Sophia
# 37 2022-01-01 10:07:23.123942      c26    o3          NaN        NaN
# 38 2022-01-01 10:07:44.419695       c9    o1          NaN  Alexandre
# 39 2022-01-01 10:11:58.523535      c27    o4     {P3, P1}        NaN
# 40 2022-01-01 10:15:29.142421      c27    o4     {P3, P1}       Noah
# 41 2022-01-01 10:18:32.366204       c9    o1          NaN        NaN
# 42 2022-01-01 10:18:52.583728      NaN    o3     {P3, P1}    Gabriel
# 43 2022-01-01 10:20:35.205708      NaN    o4     {P3, P1}       Noah
# 44 2022-01-01 10:21:45.276853      NaN    o1          NaN     Sophia
# 45 2022-01-01 10:28:03.996954      NaN    o3          NaN    Gabriel
# 46 2022-01-01 10:28:11.434362      NaN    o3          NaN     Claire
# 47 2022-01-01 10:30:35.134452      NaN    o4         {P3}   Johannes
# 48 2022-01-01 10:33:02.888922      c35    o5     {P3, P2}        NaN
# 49 2022-01-01 10:33:45.258484      c26    o3          NaN     Claire

# %%
#For every row in the dynamic attribute table
    #take the EID
    #look it up in the events_df table and retrieve the EID_new save it in a separate variable
    # put that value in the attributes table

for j in range(len(quantity_df)):
    ID = quantity_df.loc[j]['EID']
    quantity_df.loc[j]['EID'] = events_df['EID_new'].loc[events_df['EID_old'] == ID].values.tolist()[0]

for j in range(len(order_value_df)):
    ID = order_value_df.loc[j]['EID']
    order_value_df.loc[j]['EID'] = events_df['EID_new'].loc[events_df['EID_old'] == ID].values.tolist()[0]

for j in range(len(refund_df)):
    ID = refund_df.loc[j]['EID']
    refund_df.loc[j]['EID'] = events_df['EID_new'].loc[events_df['EID_old'] == ID].values.tolist()[0]

for j in range(len(shipping_method_df)):
    ID = shipping_method_df.loc[j]['EID']
    shipping_method_df.loc[j]['EID'] = events_df['EID_new'].loc[events_df['EID_old'] == ID].values.tolist()[0]

events_df= events_df.drop(['EID_old'], axis=1)
events_df.rename(columns = {'EID_new':'EID'}, inplace = True)

# %% [markdown]
# FIX QUANTITY TABLE

# %%
quantity_df[['P1','P2','P3']] =  quantity_df[['P1','P2','P3']].fillna(0)
quantity_df['Quantity']=quantity_df[['P1','P2','P3']].values.tolist()
quantity_df=quantity_df.drop(['P1','P2','P3'], axis=1)
columns_titles = ["QID","Quantity",'EID','OID']
quantity_df=quantity_df.reindex(columns=columns_titles)
quantity_df
# Out:
#    QID    Quantity   EID  OID
# 0   Q1   [3, 0, 6]    e8   o1
# 1   Q2   [4, 3, 0]    e0   o2
# 2   Q3   [7, 0, 1]    e2   o3
# 3   Q4   [3, 0, 2]   e39   o4
# 4   Q5   [0, 7, 4]   e48   o5
# 5   Q6   [0, 3, 6]   e70   o6
# 6   Q7   [3, 0, 3]  e124   o7
# 7   Q8   [3, 3, 2]  e106   o8
# 8   Q9   [2, 3, 0]   e98   o9
# 9  Q10  [0, 10, 0]   e86  o10

# %%
orders_df["Quantity"]= quantity_df['Quantity']

# %%
orders_df
# Out:
#    OID    Quantity
# 0   o1   [3, 0, 6]
# 1   o2   [4, 3, 0]
# 2   o3   [7, 0, 1]
# 3   o4   [3, 0, 2]
# 4   o5   [0, 7, 4]
# 5   o6   [0, 3, 6]
# 6   o7   [3, 0, 3]
# 7   o8   [3, 3, 2]
# 8   o9   [2, 3, 0]
# 9  o10  [0, 10, 0]

# %%
product_types_df
# Out:
#   PID  Value  Fragile
# 0  P1     15        0
# 1  P2     10        0
# 2  P3     20        1

# %%
customers_df
# Out:
#     CID               Name         Bank Account
# 0    c1         Edgar Rapp  BE68 7689 4634 2678
# 1    c2         James Dinh  BE67 7686 4647 2671
# 2    c3        Emily Hudek  BE66 7683 4660 2664
# 3    c4      Judith Duenas  BE65 7680 4673 2657
# 4    c5  Gabriel Livengood  BE64 7677 4686 2650
# 5    c6         Mindy Edge  BE63 7674 4699 2643
# 6    c7          Joyce Lee  BE62 7671 4712 2636
# 7    c8        Deena Avila  BE61 7668 4725 2629
# 8    c9    Margaret Hanson  BE60 7665 4738 2622
# 9   c10    Barbara Johnson  BE59 7662 4751 2615
# 10  c11    Jessica Estrada  BE58 7659 4764 2608
# 11  c12    Carla Fairfield  BE57 7656 4777 2601
# 12  c13      Andrew Talbot  BE56 7653 4790 2594
# 13  c14    Patricia Wrubel  BE55 7650 4803 2587
# 14  c15     Phillip Brooks  BE54 7647 4816 2580
# 15  c16    Morris Langston  BE53 7644 4829 2573
# 16  c17          Sara Vega  BE52 7641 4842 2566
# 17  c18       Odessa Lopez  BE51 7638 4855 2559
# 18  c19   Alfonso Winstead  BE50 7635 4868 2552
# 19  c20      Barbara Smith  BE49 7632 4881 2545
# 20  c21        Donna Nolte  BE48 7629 4894 2538
# 21  c22      Robert Baccam  BE47 7626 4907 2531
# 22  c23       Lane Jenkins  BE46 7623 4920 2524
# 23  c24        Kate Gainer  BE45 7620 4933 2517
# 24  c25          Arthur Vu  BE44 7617 4946 2510
# 25  c26    Dorothy Collins  BE43 7614 4959 2503
# 26  c27      Ursula Graber  BE42 7611 4972 2496
# 27  c28        Elroy Lyons  BE41 7608 4985 2489
# 28  c29     Clinton Taylor  BE40 7605 4998 2482
# 29  c30       Angela Reyes  BE39 7602 5011 2475
# 30  c31        Alia Rafter  BE38 7599 5024 2468
# 31  c32      Javier Emmick  BE37 7596 5037 2461
# 32  c33       Dennis Canup  BE36 7593 5050 2454
# 33  c34       Danny Tockey  BE35 7590 5063 2447
# 34  c35   Edward Patterson  BE34 7587 5076 2440
# 35  c36     Elizabeth Prow  BE33 7584 5089 2433
# 36  c37   Jeffrey Gallahan  BE32 7581 5102 2426
# 37  c38       James Pettit  BE31 7578 5115 2419
# 38  c39    Willie Brookins  BE30 7575 5128 2412
# 39  c40   Melinda Demarais  BE29 7572 5141 2405
# 40  c41     Marie Martinez  BE28 7569 5154 2398
# 41  c42      Richard Hanus  BE27 7566 5167 2391
# 42  c43      Dawn Marchant  BE26 7563 5180 2384
# 43  c44    William Goodrow  BE25 7560 5193 2377
# 44  c45   Consuelo Webster  BE24 7557 5206 2370
# 45  c46   Tracey Ratcliffe  BE23 7554 5219 2363
# 46  c47         Grace Wood  BE22 7551 5232 2356
# 47  c48       Susan Lipsky  BE21 7548 5245 2349
# 48  c49       Joyce Deluca  BE20 7545 5258 2342
# 49  c50        Craig Brown  BE19 7542 5271 2335

# %%
orders_df
# Out:
#    OID    Quantity
# 0   o1   [3, 0, 6]
# 1   o2   [4, 3, 0]
# 2   o3   [7, 0, 1]
# 3   o4   [3, 0, 2]
# 4   o5   [0, 7, 4]
# 5   o6   [0, 3, 6]
# 6   o7   [3, 0, 3]
# 7   o8   [3, 3, 2]
# 8   o9   [2, 3, 0]
# 9  o10  [0, 10, 0]

# %%
quantity_df
# Out:
#    QID    Quantity   EID  OID
# 0   Q1   [3, 0, 6]    e8   o1
# 1   Q2   [4, 3, 0]    e0   o2
# 2   Q3   [7, 0, 1]    e2   o3
# 3   Q4   [3, 0, 2]   e39   o4
# 4   Q5   [0, 7, 4]   e48   o5
# 5   Q6   [0, 3, 6]   e70   o6
# 6   Q7   [3, 0, 3]  e124   o7
# 7   Q8   [3, 3, 2]  e106   o8
# 8   Q9   [2, 3, 0]   e98   o9
# 9  Q10  [0, 10, 0]   e86  o10

# %%
order_value_df
# Out:
#    VID Value   EID  OID
# 0   V1   165   e10   o1
# 1   V2    90    e3   o2
# 2   V3   125   e13   o3
# 3   V4    85   e43   o4
# 4   V5   150   e51   o5
# 5   V6   150   e77   o6
# 6   V7   105  e136   o7
# 7   V8   115  e116   o8
# 8   V9    60  e105   o9
# 9  V10   100   e89  o10

# %%
refund_df
# Out:
#     RID Refund Value   EID  OID
# 0    R1            0    e8   o1
# 1    R2            0    e0   o2
# 2    R3            0    e2   o3
# 3    R4            0   e39   o4
# 4    R5            0   e48   o5
# 5    R6            1   e81   o5
# 6    R7            0  e109   o5
# 7    R8            0   e70   o6
# 8    R9            0  e124   o7
# 9   R10            1  e163   o7
# 10  R11            0  e182   o7
# 11  R12            0  e106   o8
# 12  R13            1  e159   o8
# 13  R14            0  e178   o8
# 14  R15            0   e98   o9
# 15  R16            0   e86  o10

# %%
shipping_method_df
# Out:
#     SID            Method   EID  OID
# 0    S1          Courrier   e34   o1
# 1    S2              Mail   e15   o2
# 2    S3          Courrier   e42   o3
# 3    S4          Courrier   e67   o4
# 4    S5          Courrier   e69   o5
# 5    S6  Express Courrier   e90   o5
# 6    S7          Courrier  e107   o6
# 7    S8          Courrier  e154   o7
# 8    S9  Express Courrier  e170   o7
# 9   S10          Courrier  e149   o8
# 10  S11  Express Courrier  e168   o8
# 11  S12              Mail  e142   o9
# 12  S13          Courrier  e108  o10

# %%
writer = pd.ExcelWriter('DOCEL_log_2.xlsx', engine='xlsxwriter')

# %%
# event table
events_df.to_excel(writer, sheet_name='Events')

#object tables
customers_df.to_excel(writer, sheet_name='Customer')
product_types_df.to_excel(writer, sheet_name='Product Type')
orders_df.to_excel(writer, sheet_name='Order')

#Attribute tables
#quantity_df.to_excel(writer, sheet_name='Quantity')
order_value_df.to_excel(writer, sheet_name='Value')
refund_df.to_excel(writer, sheet_name='Refund Value')
shipping_method_df.to_excel(writer, sheet_name='Method')

# %%
# Close the Pandas Excel writer and output the Excel file.
writer.save()
# Out:
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1744656341.py:2: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
#OCEL LOG

# %%
#OCEL = pd.merge(, quantity_df, how="left",on='EID')
OCEL = pd.merge(events_df, order_value_df, how="left",on='EID')
OCEL = pd.merge(OCEL, refund_df, how="left",on='EID')
OCEL = pd.merge(OCEL, shipping_method_df, how="left",on='EID')

OCEL=OCEL.fillna('/')
OCEL=OCEL.drop(['OID_x','OID_y','VID','RID','SID'], axis=1)
OCEL
# Out:
#       EID                        Activity                  Timestamp Customer  \
# 0      e0                     Place Order 2022-01-01 08:32:46.276853      c26
# 1      e1                   Receive Order 2022-01-01 08:42:16.780357      c26
# 2      e2                     Place Order 2022-01-01 08:43:59.393784      c26
# 3      e3                Confirm Purchase 2022-01-01 08:44:09.469830        /
# 4      e4  Collect product from warehouse 2022-01-01 08:45:11.063350        /
# ..    ...                             ...                        ...      ...
# 179  e179                      Pay refund 2022-01-01 14:50:12.451985      c13
# 180  e180                 Deliver package 2022-01-01 14:56:11.580975      c13
# 181  e181                      File Order 2022-01-01 14:56:22.203578        /
# 182  e182          Determine satisfaction 2022-01-01 15:00:39.898760      c13
# 183  e183                      File Order 2022-01-01 15:12:04.357141        /
#
#     Order Product Type Resource Value Refund Value Method OID
# 0      o2     {P2, P1}        /     /            0      /   /
# 1      o2     {P2, P1}   Evelyn     /            /      /   /
# 2      o3     {P3, P1}        /     /            0      /   /
# 3      o2     {P2, P1}   Evelyn    90            /      /   /
# 4      o2         {P2}    Chloe     /            /      /   /
# ..    ...          ...      ...   ...          ...    ...  ..
# 179    o7            /      Jan     /            /      /   /
# 180    o7            /    David     /            /      /   /
# 181    o8            /   Sophia     /            /      /   /
# 182    o7            /        /     /            0      /   /
# 183    o7            /      Jan     /            /      /   /
#
# [184 rows x 11 columns]

# %%
writer = pd.ExcelWriter('OCEL_log_2.xlsx', engine='xlsxwriter')

# %%
# event table
OCEL.to_excel(writer, sheet_name='Events')

#object tables
customers_df.to_excel(writer, sheet_name='Customer')
product_types_df.to_excel(writer, sheet_name='Product Type')
orders_df.to_excel(writer, sheet_name='Order')

# %%
# Close the Pandas Excel writer and output the Excel file.
writer.save()
# Out:
# /var/folders/3b/7cjmdk4d3ysg59q40b__n0mm0000gn/T/ipykernel_83197/1744656341.py:2: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
