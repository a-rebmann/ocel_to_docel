# %%
pip install random-address
# Out:
# Collecting random-address
#   Downloading random_address-1.1.1-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 9.2 MB/s eta 0:00:00
# Installing collected packages: random-address
# Successfully installed random-address-1.1.1

# %%
pip install names
# Out:
# Collecting names
#   Downloading names-0.3.0.tar.gz (789 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 789.1/789.1 kB 30.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: names
#   Building wheel for names (setup.py) ... done
#   Created wheel for names: filename=names-0.3.0-py3-none-any.whl size=803682 sha256=36965e264250752f11740420be35d6b6cf043aa33fb077d989f5e3b64d123c04
#   Stored in directory: /root/.cache/pip/wheels/fc/9a/6f/78f4282bbcaa2d8c678b73c54c0bb1b7a04009f0d7cec79fce
# Successfully built names
# Installing collected packages: names
# Successfully installed names-0.3.0

# %%
import pandas as pd
import names
import random
import time
from datetime import datetime
import numpy as np
from random import randrange
from datetime import timedelta
from random_address import real_random_address

# %%
adress = real_random_address()
print(adress)
# Out:
# {'address1': '430 Fig Street', 'address2': '', 'city': 'Madera', 'state': 'CA', 'postalCode': '93638', 'coordinates': {'lat': 36.96641109999999, 'lng': -120.0424251}}

# %%
#To generate initial timestamps

def random_date(start, end):
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    return start + timedelta(seconds=random_second)

# %% [markdown]
# Create Customers Table

# %%
customers_df = pd.DataFrame(columns = ["CID", "Name","Bank Account"])
for i in range(50):
    customers_df = customers_df.append({'CID':"c"+str(i+1),
                                        'Name':names.get_full_name(),
                                        'Bank Account': 'US'+ str(76-i)+" " + str(3456-i*3)+" "  + str(6854+i*13+67)+" "  + str(3467 - i*7 -789),
                                        } ,
                                       ignore_index=True)
customers_df
# Out:
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
# <ipython-input-37-2f4fc84d89d3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customers_df = customers_df.append({'CID':"c"+str(i+1),
#     CID                Name         Bank Account
# 0    c1      Jennifer Breau  US76 3456 6921 2678
# 1    c2     Janice Robinson  US75 3453 6934 2671
# 2    c3         Janice Park  US74 3450 6947 2664
# 3    c4       Ernie Bagshaw  US73 3447 6960 2657
# 4    c5     Margie Newberry  US72 3444 6973 2650
# 5    c6      Johnathan Blew  US71 3441 6986 2643
# 6    c7      Ronnie Allison  US70 3438 6999 2636
# 7    c8        Jerry Pinera  US69 3435 7012 2629
# 8    c9         Jackson Cox  US68 3432 7025 2622
# 9   c10        Jessie Jones  US67 3429 7038 2615
# 10  c11      Jennifer Botti  US66 3426 7051 2608
# 11  c12      Jennifer Evans  US65 3423 7064 2601
# 12  c13    Sabina Schroeder  US64 3420 7077 2594
# 13  c14        John Rosales  US63 3417 7090 2587
# 14  c15        Amy Thompson  US62 3414 7103 2580
# 15  c16      Grace Phillips  US61 3411 7116 2573
# 16  c17       Margaret Kipp  US60 3408 7129 2566
# 17  c18      Angela Soriano  US59 3405 7142 2559
# 18  c19        Jason Duncan  US58 3402 7155 2552
# 19  c20        David Barton  US57 3399 7168 2545
# 20  c21       Edmond Martin  US56 3396 7181 2538
# 21  c22          James Ronn  US55 3393 7194 2531
# 22  c23      Robert Holland  US54 3390 7207 2524
# 23  c24          John Colon  US53 3387 7220 2517
# 24  c25      George Warwick  US52 3384 7233 2510
# 25  c26      Dewayne Rivera  US51 3381 7246 2503
# 26  c27        Paula Palmer  US50 3378 7259 2496
# 27  c28   Charles Patterson  US49 3375 7272 2489
# 28  c29        Jill Shaffer  US48 3372 7285 2482
# 29  c30     Cynthia Prewitt  US47 3369 7298 2475
# 30  c31      Rickey Iraheta  US46 3366 7311 2468
# 31  c32  Elizabeth Williams  US45 3363 7324 2461
# 32  c33         Damon Nance  US44 3360 7337 2454
# 33  c34         Sandra Mone  US43 3357 7350 2447
# 34  c35     Christopher Won  US42 3354 7363 2440
# 35  c36   Charles Stevenson  US41 3351 7376 2433
# 36  c37         Nadia Eells  US40 3348 7389 2426
# 37  c38       Charles Adams  US39 3345 7402 2419
# 38  c39    Jesus Pangelinan  US38 3342 7415 2412
# 39  c40          Nick Cross  US37 3339 7428 2405
# 40  c41          John Smith  US36 3336 7441 2398
# 41  c42      Marilyn Maddox  US35 3333 7454 2391
# 42  c43     Thomas Williams  US34 3330 7467 2384
# 43  c44        Sandra Snell  US33 3327 7480 2377
# 44  c45        Karlene Gray  US32 3324 7493 2370
# 45  c46       Charles Rubin  US31 3321 7506 2363
# 46  c47       Joanne Wagner  US30 3318 7519 2356
# 47  c48     William Stewart  US29 3315 7532 2349
# 48  c49      Lauren Collins  US28 3312 7545 2342
# 49  c50       Pamela Redenz  US27 3309 7558 2335

# %% [markdown]
# Create Product list

# %%
# assign data to product list.
products_list = {'PID': ["p1",'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14',
                        'p15', 'p16', 'p17', 'p18', 'p19', 'p20'],
                 'Product Name': ["Echo Show 8",'Fire Stick 4K','Echo','Echo Studio','iPad','Kindle',
                             'iPad Air','MacBook Air',"iPhone 11","Fire Stick","iPhone 11 Pro",
                            "iPad Pro","iPhone X","Echo Dot","Kindle Paperwhite","Echo Plus","iPad mini",
                            "iPhone 8","MacBook Pro","Echo Show 5"],
                 'Price':[173.0, 146.0, 378.0, 340.0, 369.0, 255.0, 472.0, 436.0, 115.0, 460.0, 112.0, 308.0,
                         302.0, 369.0, 271.0, 122.0, 131.0, 340.0, 208.0, 218.0],
                 'Weight': [1.3, 2.4, 1.6, 1.4, 2.1, 2.3, 1.9, 2.8, 0.8, 1.2, 0.7,
                            1.4, 1.3, 1.6, 2.3, 2.8, 1.9,0.6, 3.5,2.5]}
products_df = pd.DataFrame(products_list)
products_df
# Out:
#     PID       Product Name  Price  Weight
# 0    p1        Echo Show 8  173.0     1.3
# 1    p2      Fire Stick 4K  146.0     2.4
# 2    p3               Echo  378.0     1.6
# 3    p4        Echo Studio  340.0     1.4
# 4    p5               iPad  369.0     2.1
# 5    p6             Kindle  255.0     2.3
# 6    p7           iPad Air  472.0     1.9
# 7    p8        MacBook Air  436.0     2.8
# 8    p9          iPhone 11  115.0     0.8
# 9   p10         Fire Stick  460.0     1.2
# 10  p11      iPhone 11 Pro  112.0     0.7
# 11  p12           iPad Pro  308.0     1.4
# 12  p13           iPhone X  302.0     1.3
# 13  p14           Echo Dot  369.0     1.6
# 14  p15  Kindle Paperwhite  271.0     2.3
# 15  p16          Echo Plus  122.0     2.8
# 16  p17          iPad mini  131.0     1.9
# 17  p18           iPhone 8  340.0     0.6
# 18  p19        MacBook Pro  208.0     3.5
# 19  p20        Echo Show 5  218.0     2.5

# %% [markdown]
# Create Order table

# %%
orders_df = pd.DataFrame(columns = ["OID"])

# %% [markdown]
# Create items table

# %%
items_df = pd.DataFrame(columns = ['IID', 'Price', 'Weight'])

# %% [markdown]
# Create Package table

# %%
packages_df = pd.DataFrame(columns = ['PaID', 'Price', 'Weight'])

# %% [markdown]
# Create events table and the dynamic attributes tables

# %%
events_df = pd.DataFrame(columns = ["EID", "Activity","Timestamp",
                                    'Customers','Orders',"Products","Items", "Packages"])

#Dynamic attributes of orders
order_weight_df = pd.DataFrame(columns = ["OWID", "Order_Weight","EID","OID"])
order_price_df = pd.DataFrame(columns = ["OPID", "Order_Price","EID","OID"])

#Dynamic attributes of customers
customer_adress_df = pd.DataFrame(columns = ["CAID", 'Customer_Adress', 'EID', "CID"])

# %% [markdown]
# Here we create the log itself

# %%
count = 1
Number_of_orders = 2
Max_number_of_products = 2
Max_number_of_items = 2
Remove_prob_item = 0.3
Change_adress_prob = 0.3
Fail_delivery_prob = 0.5
time_between_events= 90000

start = datetime.strptime('1/6/2022 08:30 AM', '%d/%m/%Y %I:%M %p')
end =  datetime.strptime('1/12/2022 6:00 PM', '%d/%m/%Y %I:%M %p')
customer_list= list()
product_list = list()

for i in range(0, Number_of_orders):


    #Initialize customers and retrieve CID
    customer= customers_df.sample()
    CID= customer['CID'].values


    #Initialize products
    product = products_df.sample(n=Max_number_of_products,replace=False)



    #Initialize order_weight
    order_weight = 0

    #Initialize order_price
    order_price = 0

    #Initialize timestamp
    stamp = random_date(start, end)

    #Complete itemlist of this order
    item_list2=[]

    #Add items to order
    for index, row in product.iterrows():
        product_list.append(row["PID"])
        #item_list of a specific product
        item_list=[]

        for item in range(0, random.randint(0, Max_number_of_items)+1):
            item_string = 'i'+str(len(items_df)+1)
            item_list.append(item_string)
            item_list2.append(item_string)

            #print(row["PID"],row["Product Name"], row["Price"], row['Weight'])

            #Items Table
            items_df = items_df.append({'IID': 'i'+ str(len(items_df)+1),
                                       'Price': row["Price"], 'Weight': row['Weight'],
                                       'Name': row["Product Name"] },ignore_index=True)



            #Calculate the new order_weight
            order_weight += row['Weight']


            #Calculate the new order_price
            order_price += row['Price']


        #Events Table
        events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Add items to order',
                                    'Timestamp': stamp,
                                 'Customers': CID[0],
                                 'Orders': 'o'+str(i+1),
                                 'Products': row["PID"],
                                         'Items': item_list},
                                           ignore_index=True)

        orders_df = orders_df.append({'OID': 'o'+str(i+1)},ignore_index=True)
        orders_df = orders_df.drop_duplicates()

        #Order Weight Table
        order_weight_df = order_weight_df.append({'OWID': 'OW' + str(len(order_weight_df)+1),
                                                     'Order_Weight': order_weight,
                                                     'EID': "e"+str(i+count),
                                                     'OID':'o'+str(i+1)},ignore_index=True)
        #Order Price Table
        order_price_df = order_price_df.append({'OPID': 'OW' + str(len(order_price_df)+1),
                                                     'Order_Price': order_price,
                                                     'EID': "e"+str(i+count),
                                                     'OID':'o'+str(i+1)},ignore_index=True)
        if CID[0] not in customer_list:
            #Add customer to the list
            customer_list.append(CID[0])
            #Create a random adress
            adress = real_random_address()


            customer_adress_df = customer_adress_df.append({"CAID": 'CA' + str(len(customer_adress_df)+1),
                                                           'Customer_Adress': adress['address1'] + adress['address2'] +
                                                            ' '+ adress['city'] +
                                                            ' ' + adress['state'] + ' ' + adress['postalCode'],
                                                           'EID': "e"+str(i+count),
                                                           'CID':CID[0] }, ignore_index=True)

        # Increase count
        count = count + 1

        #Increase timestamp at random between 1 and 700 seconds
        time_duration = random.uniform(1,time_between_events)

        stamp = stamp + timedelta(seconds=time_duration)


    #Create event Place Order

    #Events Table
    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Place Order',
                                    'Timestamp': stamp,
                                 'Customers': CID[0],
                                 'Orders': 'o'+str(i+1)},
                                           ignore_index=True)

    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,time_between_events)

    stamp = stamp + timedelta(seconds=time_duration)

    # Create event Pick Item

    for item in item_list2:

        #Events Table
        events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Pick Item',
                                    'Timestamp': stamp,
                                 'Customers': CID[0],
                                 'Orders': 'o'+str(i+1),
                                     'Items': item},
                                           ignore_index=True)

          # Increase count
        count = count + 1

        #Increase timestamp at random between 1 and 700 seconds
        time_duration = random.uniform(1,time_between_events)

        stamp = stamp + timedelta(seconds=time_duration)


    #Create event Remove Item
    for item in item_list2:
        if random.uniform(0, 1) < Remove_prob_item:
            #print(item)
            #Events Table
            events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Remove Item',
                                    'Timestamp': stamp,
                                 'Customers': CID[0],
                                 'Orders': 'o'+str(i+1),
                                     'Items': item},
                                           ignore_index=True)

            #Calculate the new order_weight


            order_weight = order_weight - items_df['Weight'].loc[items_df['IID']==item].item()

            #Order Weight Table
            order_weight_df = order_weight_df.append({'OWID': 'OW' + str(len(order_weight_df)+1),
                                                     'Order_Weight': order_weight,
                                                     'EID': "e"+str(i+count),
                                                     'OID':'o'+str(i+1)},ignore_index=True)

            #Calculate the new order_price
            order_price = order_price - items_df['Price'].loc[items_df['IID']==item].item()

            #Order Price Table
            order_price_df = order_price_df.append({'OPID': 'OW' + str(len(order_price_df)+1),
                                                     'Order_Price': order_price,
                                                     'EID': "e"+str(i+count),
                                                     'OID':'o'+str(i+1)},ignore_index=True)

            item_list2.remove(item)

            # Increase count
            count = count + 1

            #Increase timestamp at random between 1 and 700 seconds
            time_duration = random.uniform(1,time_between_events)

            stamp = stamp + timedelta(seconds=time_duration)


    #Create event Pay Order
    #Events Table
    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Pay Order',
                                    'Timestamp': stamp,
                                 'Customers': CID[0],
                                 'Orders': 'o'+str(i+1)},
                                           ignore_index=True)

    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,time_between_events)

    stamp = stamp + timedelta(seconds=time_duration)

    #Create event Create Package

    #Events Table
    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Create Package',
                                    'Timestamp': stamp,
                                 'Customers': CID[0],
                                 'Orders': 'o'+str(i+1),
                                  'Items': item_list2,
                                 'Packages': 'pa' + str(len(packages_df)+1)},
                                           ignore_index=True)
    if len(packages_df) != i+count:
      packages_df = packages_df.append({'PaID':'pa' + str(len(packages_df)+1), 'Price': order_price,
                                     'Weight': order_weight}, ignore_index=True)

    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,time_between_events)

    stamp = stamp + timedelta(seconds=time_duration)


    #Events Table
    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Send Package',
                                    'Timestamp': stamp,
                                 'Customers': CID[0],
                                 'Orders': 'o'+str(i+1),
                                 'Packages': 'pa' + str(len(packages_df))},
                                           ignore_index=True)

    # Increase count
    count = count + 1

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,time_between_events)

    stamp = stamp + timedelta(seconds=time_duration)

    #Change adress with a certain probability
    if random.uniform(0, 1) < Change_adress_prob:

        events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Change Adress',
                                    'Timestamp': stamp,
                                 'Customers': CID[0],
                                 'Orders': 'o'+str(i+1),
                                 'Packages': 'pa' + str(len(packages_df))},
                                           ignore_index=True)

        #Create a random adress
        adress = real_random_address()


        customer_adress_df = customer_adress_df.append({"CAID": 'CA' + str(len(customer_adress_df)+1),
                                                           'Customer_Adress': adress['address1'] +
                                                        adress['address2'] + ' '+ adress['city'] +
                                                        ' ' + adress['state'] + ' ' + adress['postalCode'],
                                                           'EID': "e"+str(i+count),
                                                           'CID':CID[0] }, ignore_index=True)

        # Increase count
        count = count + 1

        #Increase timestamp at random between 1 and 700 seconds
        time_duration = random.uniform(1,time_between_events)

        stamp = stamp + timedelta(seconds=time_duration)


        events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Fail Delivery',
                                    'Timestamp': stamp,
                                 'Orders': 'o'+str(i+1),
                                 'Packages': 'pa' + str(len(packages_df))},
                                           ignore_index=True)

        # Increase count
        count = count + 1

        #Increase timestamp at random between 1 and 700 seconds
        time_duration = random.uniform(1,time_between_events)

        stamp = stamp + timedelta(seconds=time_duration)


    #Keep failing delivery with a certain probability
    while random.uniform(0, 1) < Fail_delivery_prob:

        events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Fail Delivery',
                                    'Timestamp': stamp,
                                 'Orders': 'o'+str(i+1),
                                 'Packages': 'pa' + str(len(packages_df))},
                                           ignore_index=True)

        # Increase count
        count = count + 1

        #Increase timestamp at random between 1 and 700 seconds
        time_duration = random.uniform(1,time_between_events)

        stamp = stamp + timedelta(seconds=time_duration)



    #Create event Deliver Package

    events_df = events_df.append({'EID':"e"+str(i+count),
                                  'Activity':'Deliver Package',
                                    'Timestamp': stamp,
                                 'Customers': CID[0],
                                 'Orders': 'o'+str(i+1),
                                 'Packages': 'pa' + str(len(packages_df))},
                                           ignore_index=True)

    #Increase timestamp at random between 1 and 700 seconds
    time_duration = random.uniform(1,time_between_events)

    stamp = stamp + timedelta(seconds=time_duration)
# Out:
# <ipython-input-43-44a5aaab15cb>:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   items_df = items_df.append({'IID': 'i'+ str(len(items_df)+1),
# <ipython-input-43-44a5aaab15cb>:69: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df = orders_df.append({'OID': 'o'+str(i+1)},ignore_index=True)
# <ipython-input-43-44a5aaab15cb>:82: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_weight_df = order_weight_df.append({'OWID': 'OW' + str(len(order_weight_df)+1),
# <ipython-input-43-44a5aaab15cb>:87: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_price_df = order_price_df.append({'OPID': 'OW' + str(len(order_price_df)+1),
# <ipython-input-43-44a5aaab15cb>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customer_adress_df = customer_adress_df.append({"CAID": 'CA' + str(len(customer_adress_df)+1),
# <ipython-input-43-44a5aaab15cb>:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   items_df = items_df.append({'IID': 'i'+ str(len(items_df)+1),
# <ipython-input-43-44a5aaab15cb>:69: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df = orders_df.append({'OID': 'o'+str(i+1)},ignore_index=True)
# <ipython-input-43-44a5aaab15cb>:82: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_weight_df = order_weight_df.append({'OWID': 'OW' + str(len(order_weight_df)+1),
# <ipython-input-43-44a5aaab15cb>:87: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_price_df = order_price_df.append({'OPID': 'OW' + str(len(order_price_df)+1),
# <ipython-input-43-44a5aaab15cb>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:137: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:137: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:159: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:173: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_weight_df = order_weight_df.append({'OWID': 'OW' + str(len(order_weight_df)+1),
# <ipython-input-43-44a5aaab15cb>:182: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_price_df = order_price_df.append({'OPID': 'OW' + str(len(order_price_df)+1),
# <ipython-input-43-44a5aaab15cb>:200: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:218: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:227: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   packages_df = packages_df.append({'PaID':'pa' + str(len(packages_df)+1), 'Price': order_price,
# <ipython-input-43-44a5aaab15cb>:240: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:306: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:325: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   items_df = items_df.append({'IID': 'i'+ str(len(items_df)+1),
# <ipython-input-43-44a5aaab15cb>:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   items_df = items_df.append({'IID': 'i'+ str(len(items_df)+1),
# <ipython-input-43-44a5aaab15cb>:69: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df = orders_df.append({'OID': 'o'+str(i+1)},ignore_index=True)
# <ipython-input-43-44a5aaab15cb>:82: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_weight_df = order_weight_df.append({'OWID': 'OW' + str(len(order_weight_df)+1),
# <ipython-input-43-44a5aaab15cb>:87: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_price_df = order_price_df.append({'OPID': 'OW' + str(len(order_price_df)+1),
# <ipython-input-43-44a5aaab15cb>:98: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customer_adress_df = customer_adress_df.append({"CAID": 'CA' + str(len(customer_adress_df)+1),
# <ipython-input-43-44a5aaab15cb>:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   items_df = items_df.append({'IID': 'i'+ str(len(items_df)+1),
# <ipython-input-43-44a5aaab15cb>:69: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:78: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   orders_df = orders_df.append({'OID': 'o'+str(i+1)},ignore_index=True)
# <ipython-input-43-44a5aaab15cb>:82: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_weight_df = order_weight_df.append({'OWID': 'OW' + str(len(order_weight_df)+1),
# <ipython-input-43-44a5aaab15cb>:87: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   order_price_df = order_price_df.append({'OPID': 'OW' + str(len(order_price_df)+1),
# <ipython-input-43-44a5aaab15cb>:117: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:137: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:137: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:137: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:200: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:218: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:227: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   packages_df = packages_df.append({'PaID':'pa' + str(len(packages_df)+1), 'Price': order_price,
# <ipython-input-43-44a5aaab15cb>:240: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:259: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:271: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   customer_adress_df = customer_adress_df.append({"CAID": 'CA' + str(len(customer_adress_df)+1),
# <ipython-input-43-44a5aaab15cb>:287: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:306: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:306: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),
# <ipython-input-43-44a5aaab15cb>:325: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   events_df = events_df.append({'EID':"e"+str(i+count),

# %%
#First order events by timestamps
events_df = pd.DataFrame(events_df)
events_df = events_df.sort_values(by=['Timestamp'])
#Reset the indexes
events_df= events_df.reset_index(drop=True)
events_df= events_df.reset_index()
#Rename column names
events_df=events_df.rename(columns = {'index':'EID_new', 'EID':'EID_old'})
#Rename the values of 'EID_new'
events_df['EID_new'] = events_df['EID_new']+1
events_df['EID_new'] = events_df['EID_new'].astype(str)
events_df['EID_new'] = "e" + events_df['EID_new']
events_df
# Out:
#    EID_new EID_old            Activity                  Timestamp Customers  \
# 0       e1     e12  Add items to order 2022-06-04 07:58:10.000000       c28
# 1       e2     e13  Add items to order 2022-06-04 19:24:36.924040       c28
# 2       e3     e14         Place Order 2022-06-05 12:01:24.822379       c28
# 3       e4     e15           Pick Item 2022-06-06 00:49:56.615428       c28
# 4       e5     e16           Pick Item 2022-06-06 21:44:54.746030       c28
# 5       e6     e17           Pick Item 2022-06-07 03:30:22.616614       c28
# 6       e7     e18           Pay Order 2022-06-07 10:57:45.577689       c28
# 7       e8     e19      Create Package 2022-06-08 04:29:42.673013       c28
# 8       e9     e20        Send Package 2022-06-08 11:18:10.577475       c28
# 9      e10     e21       Change Adress 2022-06-09 03:57:14.712238       c28
# 10     e11     e22       Fail Delivery 2022-06-09 18:21:12.877234       NaN
# 11     e12     e23       Fail Delivery 2022-06-10 15:50:09.146806       NaN
# 12     e13     e24       Fail Delivery 2022-06-10 23:13:59.782456       NaN
# 13     e14     e25     Deliver Package 2022-06-11 12:01:31.395998       c28
# 14     e15      e1  Add items to order 2022-09-01 23:19:18.000000       c39
# 15     e16      e2  Add items to order 2022-09-02 20:48:27.003663       c39
# 16     e17      e3         Place Order 2022-09-03 00:04:16.061032       c39
# 17     e18      e4           Pick Item 2022-09-03 08:35:29.517742       c39
# 18     e19      e5           Pick Item 2022-09-04 05:56:07.808705       c39
# 19     e20      e6         Remove Item 2022-09-04 08:24:44.059475       c39
# 20     e21      e7           Pay Order 2022-09-04 23:06:40.812511       c39
# 21     e22      e8      Create Package 2022-09-05 21:05:10.628933       c39
# 22     e23      e9        Send Package 2022-09-05 21:18:21.139661       c39
# 23     e24     e10       Fail Delivery 2022-09-05 22:05:53.809342       NaN
# 24     e25     e11     Deliver Package 2022-09-06 14:52:25.756950       c39
#
#    Orders Products         Items Packages
# 0      o2      p15      [i3, i4]      NaN
# 1      o2       p5          [i5]      NaN
# 2      o2      NaN           NaN      NaN
# 3      o2      NaN            i3      NaN
# 4      o2      NaN            i4      NaN
# 5      o2      NaN            i5      NaN
# 6      o2      NaN           NaN      NaN
# 7      o2      NaN  [i3, i4, i5]      pa2
# 8      o2      NaN           NaN      pa2
# 9      o2      NaN           NaN      pa2
# 10     o2      NaN           NaN      pa2
# 11     o2      NaN           NaN      pa2
# 12     o2      NaN           NaN      pa2
# 13     o2      NaN           NaN      pa2
# 14     o1       p8          [i1]      NaN
# 15     o1       p6          [i2]      NaN
# 16     o1      NaN           NaN      NaN
# 17     o1      NaN            i1      NaN
# 18     o1      NaN            i2      NaN
# 19     o1      NaN            i2      NaN
# 20     o1      NaN           NaN      NaN
# 21     o1      NaN          [i1]      pa1
# 22     o1      NaN           NaN      pa1
# 23     o1      NaN           NaN      pa1
# 24     o1      NaN           NaN      pa1

# %%
#For every row in the dynamic attribute table
    #take the EID
    #look it up in the events_df table and retrieve the EID_new save it in a separate variable
    # put that value in the attributes table

for j in range(len(order_weight_df)):
    ID = order_weight_df.loc[j]['EID']
    #order_weight_df.loc[j]['EID'] = events_df['EID_new'].loc[events_df['EID_old'] == ID].values.tolist()
    order_weight_df.at[j, 'EID'] = events_df['EID_new'].loc[events_df['EID_old'] == ID].values.tolist()[0]

# %%
for j in range(len(order_price_df)):
    ID2 = order_price_df.loc[j]['EID']
    order_price_df.at[j, 'EID'] = events_df['EID_new'].loc[events_df['EID_old'] == ID2].values.tolist()[0]

# %%
for j in range(len(customer_adress_df)):
    ID3 = customer_adress_df.loc[j]['EID']
    customer_adress_df.at[j, 'EID'] = events_df['EID_new'].loc[events_df['EID_old'] == ID3].values.tolist()[0]

# %%
events_df = events_df.drop(['EID_old'], axis=1)
events_df.rename(columns = {'EID_new':'EID'}, inplace = True)
events_df = events_df.fillna('/')
events_df.head(50)
# Out:
#     EID            Activity                  Timestamp Customers Orders  \
# 0    e1  Add items to order 2022-06-04 07:58:10.000000       c28     o2
# 1    e2  Add items to order 2022-06-04 19:24:36.924040       c28     o2
# 2    e3         Place Order 2022-06-05 12:01:24.822379       c28     o2
# 3    e4           Pick Item 2022-06-06 00:49:56.615428       c28     o2
# 4    e5           Pick Item 2022-06-06 21:44:54.746030       c28     o2
# 5    e6           Pick Item 2022-06-07 03:30:22.616614       c28     o2
# 6    e7           Pay Order 2022-06-07 10:57:45.577689       c28     o2
# 7    e8      Create Package 2022-06-08 04:29:42.673013       c28     o2
# 8    e9        Send Package 2022-06-08 11:18:10.577475       c28     o2
# 9   e10       Change Adress 2022-06-09 03:57:14.712238       c28     o2
# 10  e11       Fail Delivery 2022-06-09 18:21:12.877234         /     o2
# 11  e12       Fail Delivery 2022-06-10 15:50:09.146806         /     o2
# 12  e13       Fail Delivery 2022-06-10 23:13:59.782456         /     o2
# 13  e14     Deliver Package 2022-06-11 12:01:31.395998       c28     o2
# 14  e15  Add items to order 2022-09-01 23:19:18.000000       c39     o1
# 15  e16  Add items to order 2022-09-02 20:48:27.003663       c39     o1
# 16  e17         Place Order 2022-09-03 00:04:16.061032       c39     o1
# 17  e18           Pick Item 2022-09-03 08:35:29.517742       c39     o1
# 18  e19           Pick Item 2022-09-04 05:56:07.808705       c39     o1
# 19  e20         Remove Item 2022-09-04 08:24:44.059475       c39     o1
# 20  e21           Pay Order 2022-09-04 23:06:40.812511       c39     o1
# 21  e22      Create Package 2022-09-05 21:05:10.628933       c39     o1
# 22  e23        Send Package 2022-09-05 21:18:21.139661       c39     o1
# 23  e24       Fail Delivery 2022-09-05 22:05:53.809342         /     o1
# 24  e25     Deliver Package 2022-09-06 14:52:25.756950       c39     o1
#
#    Products         Items Packages
# 0       p15      [i3, i4]        /
# 1        p5          [i5]        /
# 2         /             /        /
# 3         /            i3        /
# 4         /            i4        /
# 5         /            i5        /
# 6         /             /        /
# 7         /  [i3, i4, i5]      pa2
# 8         /             /      pa2
# 9         /             /      pa2
# 10        /             /      pa2
# 11        /             /      pa2
# 12        /             /      pa2
# 13        /             /      pa2
# 14       p8          [i1]        /
# 15       p6          [i2]        /
# 16        /             /        /
# 17        /            i1        /
# 18        /            i2        /
# 19        /            i2        /
# 20        /             /        /
# 21        /          [i1]      pa1
# 22        /             /      pa1
# 23        /             /      pa1
# 24        /             /      pa1

# %%
#Only keep the relevant customers and products that occur in the log

customers_df = customers_df.loc[customers_df['CID'].isin(customer_list)]
customers_df=customers_df.reset_index(drop=True)
customers_df.head()

products_df = products_df.loc[products_df['PID'].isin(product_list)]
products_df=products_df.reset_index(drop=True)
products_df.head()
# Out:
#    PID   Product Name  Price  Weight
# 0   p1    Echo Show 8  173.0     1.3
# 1   p2  Fire Stick 4K  146.0     2.4
# 2   p8    MacBook Air  436.0     2.8
# 3  p10     Fire Stick  460.0     1.2

# %%
customer_adress_df
# Out:
#   CAID                            Customer_Adress  EID  CID
# 0  CA1  60 Bagley Street Saint Johnsbury VT 05819   e1  c35
# 1  CA2    1456 East 39th Street Savannah GA 31404  e14  c13

# %%
order_weight_df
# Out:
#   OWID  Order_Weight  EID OID
# 0  OW1           8.4   e1  o1
# 1  OW2          10.8   e2  o1
# 2  OW3           8.0   e8  o1
# 3  OW4           5.2   e9  o1
# 4  OW5           3.6  e14  o2
# 5  OW6           7.5  e15  o2
# 6  OW7           6.2  e23  o2
# 7  OW8           4.9  e24  o2

# %%
order_price_df
# Out:
#   OPID  Order_Price  EID OID
# 0  OW1       1308.0   e1  o1
# 1  OW2       1454.0   e2  o1
# 2  OW3       1018.0   e8  o1
# 3  OW4        582.0   e9  o1
# 4  OW5       1380.0  e14  o2
# 5  OW6       1899.0  e15  o2
# 6  OW7       1726.0  e23  o2
# 7  OW8       1553.0  e24  o2

# %%
items_df
# Out:
#    IID  Price  Weight           Name
# 0   i1  436.0     2.8    MacBook Air
# 1   i2  436.0     2.8    MacBook Air
# 2   i3  436.0     2.8    MacBook Air
# 3   i4  146.0     2.4  Fire Stick 4K
# 4   i5  460.0     1.2     Fire Stick
# 5   i6  460.0     1.2     Fire Stick
# 6   i7  460.0     1.2     Fire Stick
# 7   i8  173.0     1.3    Echo Show 8
# 8   i9  173.0     1.3    Echo Show 8
# 9  i10  173.0     1.3    Echo Show 8

# %%
packages_df
# Out:
#   PaID   Price  Weight
# 0  pa1   582.0     5.2
# 1  pa2  1553.0     4.9

# %% [markdown]
# Create DOCEL log format

# %%
writer = pd.ExcelWriter('DOCEL_log_1.xlsx', engine='xlsxwriter')

# event table
events_df.to_excel(writer, sheet_name='Events')

#object tables
customers_df.to_excel(writer, sheet_name='Customers')
orders_df.to_excel(writer, sheet_name='Orders')
products_df.to_excel(writer, sheet_name='Products')
items_df.to_excel(writer,sheet_name='Items')
packages_df.to_excel(writer,sheet_name='Packages')

#Attribute tables
customer_adress_df.to_excel(writer, sheet_name='Customer Adress')
order_weight_df.to_excel(writer, sheet_name='Order Weight')
order_price_df.to_excel(writer, sheet_name='Order Price')

# %%
# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
order_weight_df
# Out:
#   OWID  Order_Weight  EID OID
# 0  OW1           8.4   e1  o1
# 1  OW2          10.8   e2  o1
# 2  OW3           8.0   e8  o1
# 3  OW4           5.2   e9  o1
# 4  OW5           3.6  e14  o2
# 5  OW6           7.5  e15  o2
# 6  OW7           6.2  e23  o2
# 7  OW8           4.9  e24  o2

# %% [markdown]
# Let us now create the OCEL log

# %%
OCEL = pd.merge(events_df, customer_adress_df, how="left",on='EID')
OCEL = pd.merge(OCEL, order_weight_df, how="left",on='EID')
OCEL = pd.merge(OCEL, order_price_df, how="left",on='EID')
OCEL=OCEL.drop(['CAID', 'CID','OWID','OID_x','OPID','OID_y'], axis=1)
OCEL=OCEL.fillna('/')
OCEL
# Out:
#     EID            Activity                  Timestamp Customers Orders  \
# 0    e1  Add items to order 2022-09-08 17:47:17.000000       c35     o1
# 1    e2  Add items to order 2022-09-09 03:47:43.841376       c35     o1
# 2    e3         Place Order 2022-09-09 03:51:54.726119       c35     o1
# 3    e4           Pick Item 2022-09-10 01:54:40.144265       c35     o1
# 4    e5           Pick Item 2022-09-10 07:01:33.486915       c35     o1
# 5    e6           Pick Item 2022-09-10 08:25:57.664394       c35     o1
# 6    e7           Pick Item 2022-09-10 10:38:19.741199       c35     o1
# 7    e8         Remove Item 2022-09-11 08:35:22.302999       c35     o1
# 8    e9         Remove Item 2022-09-11 08:51:02.240836       c35     o1
# 9   e10           Pay Order 2022-09-12 06:00:45.774093       c35     o1
# 10  e11      Create Package 2022-09-12 10:38:35.352365       c35     o1
# 11  e12        Send Package 2022-09-13 08:46:52.641402       c35     o1
# 12  e13     Deliver Package 2022-09-14 06:00:37.772622       c35     o1
# 13  e14  Add items to order 2022-10-19 02:11:09.000000       c13     o2
# 14  e15  Add items to order 2022-10-19 23:06:52.390116       c13     o2
# 15  e16         Place Order 2022-10-20 19:50:10.302755       c13     o2
# 16  e17           Pick Item 2022-10-21 14:53:29.761138       c13     o2
# 17  e18           Pick Item 2022-10-22 11:28:47.324658       c13     o2
# 18  e19           Pick Item 2022-10-23 03:16:46.045649       c13     o2
# 19  e20           Pick Item 2022-10-23 18:23:34.137072       c13     o2
# 20  e21           Pick Item 2022-10-24 06:16:53.760434       c13     o2
# 21  e22           Pick Item 2022-10-24 12:34:27.437522       c13     o2
# 22  e23         Remove Item 2022-10-24 19:05:09.796947       c13     o2
# 23  e24         Remove Item 2022-10-25 16:05:10.630357       c13     o2
# 24  e25           Pay Order 2022-10-26 15:29:17.914975       c13     o2
# 25  e26      Create Package 2022-10-27 12:32:13.630343       c13     o2
# 26  e27        Send Package 2022-10-28 10:32:22.855406       c13     o2
# 27  e28     Deliver Package 2022-10-28 21:15:00.638496       c13     o2
#
#    Products             Items Packages  \
# 0        p8      [i1, i2, i3]        /
# 1        p2              [i4]        /
# 2         /                 /        /
# 3         /                i1        /
# 4         /                i2        /
# 5         /                i3        /
# 6         /                i4        /
# 7         /                i1        /
# 8         /                i3        /
# 9         /                 /        /
# 10        /          [i2, i4]      pa1
# 11        /                 /      pa2
# 12        /                 /      pa2
# 13      p10      [i5, i6, i7]        /
# 14       p1     [i8, i9, i10]        /
# 15        /                 /        /
# 16        /                i5        /
# 17        /                i6        /
# 18        /                i7        /
# 19        /                i8        /
# 20        /                i9        /
# 21        /               i10        /
# 22        /                i8        /
# 23        /               i10        /
# 24        /                 /        /
# 25        /  [i5, i6, i7, i9]      pa2
# 26        /                 /      pa3
# 27        /                 /      pa3
#
#                               Customer_Adress Order_Weight Order_Price
# 0   60 Bagley Street Saint Johnsbury VT 05819          8.4      1308.0
# 1                                           /         10.8      1454.0
# 2                                           /            /           /
# 3                                           /            /           /
# 4                                           /            /           /
# 5                                           /            /           /
# 6                                           /            /           /
# 7                                           /          8.0      1018.0
# 8                                           /          5.2       582.0
# 9                                           /            /           /
# 10                                          /            /           /
# 11                                          /            /           /
# 12                                          /            /           /
# 13    1456 East 39th Street Savannah GA 31404          3.6      1380.0
# 14                                          /          7.5      1899.0
# 15                                          /            /           /
# 16                                          /            /           /
# 17                                          /            /           /
# 18                                          /            /           /
# 19                                          /            /           /
# 20                                          /            /           /
# 21                                          /            /           /
# 22                                          /          6.2      1726.0
# 23                                          /          4.9      1553.0
# 24                                          /            /           /
# 25                                          /            /           /
# 26                                          /            /           /
# 27                                          /            /           /

# %%
#Export the OCEL log
writer = pd.ExcelWriter('OCEL_log_1.xlsx', engine='xlsxwriter')

# event table
OCEL.to_excel(writer, sheet_name='Events')

#object tables
customers_df.to_excel(writer, sheet_name='Customers')
orders_df.to_excel(writer, sheet_name='Orders')
products_df.to_excel(writer, sheet_name='Products')
items_df.to_excel(writer,sheet_name='Items')
packages_df.to_excel(writer,sheet_name='Packages')

# %%
# Close the Pandas Excel writer and output the Excel file.
writer.save()
